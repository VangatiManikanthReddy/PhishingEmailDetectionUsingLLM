# %% [markdown]
# <a href="https://colab.research.google.com/github/VangatiManikanthReddy/PhishingEmailDetectionUsingLLM/blob/testbranch/new_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environment Setup and Access

# %%
# ✅ Check Python version
# !python --version
# Out:
# Python 3.11.12

# %%
# ✅ Import libraries
import os
import pandas as pd
import numpy as np
from google.colab import drive
from openai import OpenAI
from google.colab import userdata

# %%
client = OpenAI(api_key = userdata.get('OPENAI_API_KEY'))

# %% [markdown]
# # Google drive integration  and data loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -U gdown
# Out:
# Mounted at /content/drive
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --folder https://drive.google.com/drive/folders/1IhTy0VlkN6SEafeF3i8THixz7flOe_sl -O ALLAPIS --quiet

# %%
# Define the path to the CSV file inside your custom folder
csv_path = '/content/ALLAPIS/CEAS_08.csv'

# Check if file exists and load it
if os.path.exists(csv_path):
    print("✅ File found! Reading the CSV now...\n")
    df = pd.read_csv(csv_path)
   # display(df.head(10))  # Display first 10 rows
else:
    print("❌ File not found at:", csv_path)
# Out:
# ✅ File found! Reading the CSV now...

# %%
# Locating the file in the drive
import os

def find_folder_path(folder_name, base_path='/content/'):
    for root, dirs, files in os.walk(base_path):
        if folder_name in dirs:
            return os.path.join(root, folder_name)
    return None

# %%
# Printing the path of the file
folder_name_to_search = '04 Manikanth and Anjireddy'
path = "/content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy"
print(path)
# /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy
# Out:
# /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy

# %%
# Printing Raw data set
from google.colab import data_table
from vega_datasets import data

data_table.enable_dataframe_formatter()
df.head(3)
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
#
#                         receiver                             date  \
# 0    user4@gvc.ceas-challenge.cc  Tue, 05 Aug 2008 16:31:02 -0700
# 1  user2.2@gvc.ceas-challenge.cc  Tue, 05 Aug 2008 18:31:03 -0500
# 2  user2.9@gvc.ceas-challenge.cc  Tue, 05 Aug 2008 20:28:00 -1200
#
#                      subject  \
# 0  Never agree to be a loser
# 1     Befriend Jenna Jameson
# 2       CNN.com Daily Top 10
#
#                                                 body  label  urls
# 0  Buck up, your troubles caused by small dimensi...      1     1
# 1  \nUpgrade your sex and pleasures with these te...      1     1
# 2  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1

# %%
print(path)
# Out:
# /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy

# %% [markdown]
# # preprocessing the data like remove duplicates and missing values

# %%
#  Step 1: Remove duplicate rows
df = df.drop_duplicates()
from google.colab import data_table
from IPython.display import HTML
# df1 = df.head(3)
# data_table.DataTable(df)
data_table.DataTable(df.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#       <th>urls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Step 2: Remove rows with any missing (NaN) values
df = df.dropna()
data_table.DataTable(df.head(2), include_index=True, num_rows_per_page=5)

# print(df1.head(3))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#       <th>urls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Optional: Reset index for clean row numbering
df.reset_index(drop=True, inplace=True)
data_table.DataTable(df.head(2), include_index=True, num_rows_per_page=5)
# print(df1.head(3))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#       <th>urls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# ✅ 📄 Load Cleaned File + Range Display Function
# Step 1: Load the cleaned CSV from original_data folder
df = pd.read_csv('/content/ALLAPIS/CEAS_08.csv')

# %%
# printing the cleaned data
from google.colab import data_table
from vega_datasets import data

data_table.enable_dataframe_formatter()
df.head(10)
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                 Michael Parker <ivqrnai@pobox.com>
# 4  Gretchen Suggs <externalsep1@loanofficertool.com>
# 5  Caroline Aragon <dwthaidomainnamesm@thaidomain...
# 6    Replica Watches <jhorton@thebakercompanies.com>
# 7             Daily Top 10 <acidirev_1972@tcwpg.com>
# 8                  qydlqcws-iacfym@issues.apache.org
# 9      Daily Top 10 <orn|dent_1973@musicaedischi.it>
#
#                                          receiver  \
# 0                     user4@gvc.ceas-challenge.cc
# 1                   user2.2@gvc.ceas-challenge.cc
# 2                   user2.9@gvc.ceas-challenge.cc
# 3  SpamAssassin Dev <xrh@spamassassin.apache.org>
# 4                   user2.2@gvc.ceas-challenge.cc
# 5                user7-ext5@gvc.ceas-challenge.cc
# 6                  user2.10@gvc.ceas-challenge.cc
# 7                   user2.3@gvc.ceas-challenge.cc
# 8                     xrh@spamassassin.apache.org
# 9                     user7@gvc.ceas-challenge.cc
#
#                               date  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700
# 1  Tue, 05 Aug 2008 18:31:03 -0500
# 2  Tue, 05 Aug 2008 20:28:00 -1200
# 3  Tue, 05 Aug 2008 17:31:20 -0600
# 4  Tue, 05 Aug 2008 19:31:21 -0400
# 5  Wed, 06 Aug 2008 05:31:22 +0600
# 6  Tue, 05 Aug 2008 21:44:01 +0000
# 7  Tue, 05 Aug 2008 20:41:14 -0300
# 8  Tue, 05 Aug 2008 15:31:03 -0800
# 9  Wed, 06 Aug 2008 00:31:38 +0100
#
#                                              subject  \
# 0                          Never agree to be a loser
# 1                             Befriend Jenna Jameson
# 2                               CNN.com Daily Top 10
# 3  Re: svn commit: r619753 - in /spamassassin/tru...
# 4                         SpecialPricesPharmMoreinfo
# 5                               From Caroline Aragon
# 6                                    Replica Watches
# 7                               CNN.com Daily Top 10
# 8  [Bug 5780] URI processing turns uuencoded stri...
# 9                               CNN.com Daily Top 10
#
#                                                 body  label  urls
# 0  Buck up, your troubles caused by small dimensi...      1     1
# 1  \nUpgrade your sex and pleasures with these te...      1     1
# 2  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1
# 3  Would anyone object to removing .so from this ...      0     1
# 4  \nWelcomeFastShippingCustomerSupport\nhttp://7...      1     1
# 5  \n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...      1     0
# 6  We have fake Swiss Men's and Ladie's Replica \...      1     0
# 7  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1
# 8  http://issues.apache.org/SpamAssassin/show_bug...      0     1
# 9  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1

# %%
# Define path to save the cleaned file
save_path = '/content/ALLAPIS/cleaned_data.csv'

# Save the cleaned DataFrame as CSV
df.to_csv(save_path, index=False)

print(f"✅ Cleaned data saved to: {save_path}")
# Out:
# ✅ Cleaned data saved to: /content/ALLAPIS/cleaned_data.csv

# %% [markdown]
# # Extracting the data into header,body and header and body

# %% [markdown]
# ##Data with labels

# %%
#  Header-only DataFrame with label
df_header_label = df[['sender', 'receiver', 'date', 'subject', 'label']].copy()
data_table.DataTable(df_header_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#  Body-only DataFrame with label
df_body_label = df[['body','label']].copy()
data_table.DataTable(df_body_label.head(10), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>body</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Would anyone object to removing .so from this ...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>\nWelcomeFastShippingCustomerSupport\nhttp://7...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>\n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>We have fake Swiss Men's and Ladie's Replica \...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://issues.apache.org/SpamAssassin/show_bug...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# getting header and body  with label
df_header_body_label = df[['sender', 'receiver', 'date', 'subject', 'body','label']].copy()
data_table.DataTable(df_header_body_label.head(10), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Daily Top 10 &lt;Karmandeep-opengevl@universalnet...</td>
#       <td>user2.9@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 20:28:00 -1200</td>
#       <td>CNN.com Daily Top 10</td>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Michael Parker &lt;ivqrnai@pobox.com&gt;</td>
#       <td>SpamAssassin Dev &lt;xrh@spamassassin.apache.org&gt;</td>
#       <td>Tue, 05 Aug 2008 17:31:20 -0600</td>
#       <td>Re: svn commit: r619753 - in /spamassassin/tru...</td>
#       <td>Would anyone object to removing .so from this ...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Gretchen Suggs &lt;externalsep1@loanofficertool.com&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 19:31:21 -0400</td>
#       <td>SpecialPricesPharmMoreinfo</td>
#       <td>\nWelcomeFastShippingCustomerSupport\nhttp://7...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Caroline Aragon &lt;dwthaidomainnamesm@thaidomain...</td>
#       <td>user7-ext5@gvc.ceas-challenge.cc</td>
#       <td>Wed, 06 Aug 2008 05:31:22 +0600</td>
#       <td>From Caroline Aragon</td>
#       <td>\n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Replica Watches &lt;jhorton@thebakercompanies.com&gt;</td>
#       <td>user2.10@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 21:44:01 +0000</td>
#       <td>Replica Watches</td>
#       <td>We have fake Swiss Men's and Ladie's Replica \...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Daily Top 10 &lt;acidirev_1972@tcwpg.com&gt;</td>
#       <td>user2.3@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 20:41:14 -0300</td>
#       <td>CNN.com Daily Top 10</td>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>qydlqcws-iacfym@issues.apache.org</td>
#       <td>xrh@spamassassin.apache.org</td>
#       <td>Tue, 05 Aug 2008 15:31:03 -0800</td>
#       <td>[Bug 5780] URI processing turns uuencoded stri...</td>
#       <td>http://issues.apache.org/SpamAssassin/show_bug...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Daily Top 10 &lt;orn|dent_1973@musicaedischi.it&gt;</td>
#       <td>user7@gvc.ceas-challenge.cc</td>
#       <td>Wed, 06 Aug 2008 00:31:38 +0100</td>
#       <td>CNN.com Daily Top 10</td>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Define your full target path
submission_folder = path
print(submission_folder)
gpt_llm_path = os.path.join(submission_folder,'001 Submission','All APIs',  'gpt_llm', 'raw_data','Data_with_label')

#  Create the directory structure
os.makedirs(gpt_llm_path, exist_ok=True)

# Save the 3 labeled DataFrames to the new location

# 1. Header with label
df_header_label.to_csv(os.path.join(gpt_llm_path, 'header_with_label.csv'), index=False)

# 2. Body with label
df_body_label.to_csv(os.path.join(gpt_llm_path, 'body_with_label.csv'), index=False)

# 3. Combined Header + Body with label
df_header_body_label.to_csv(os.path.join(gpt_llm_path, 'header_body_with_label.csv'), index=False)

print(f"✅ All files saved successfully to: {gpt_llm_path}")
# Out:
# /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy
# ✅ All files saved successfully to: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/raw_data/Data_with_label

# %% [markdown]
# ##Data without label

# %%
#. Header-only DataFrame with no label
df_header_label = df[['sender', 'receiver', 'date', 'subject']].copy()
data_table.DataTable(df_header_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Body-only DataFrame with no label
df_body_label = df[['body']].copy()
data_table.DataTable(df_body_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>body</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#  Combined header + body DataFrame with no label
df_header_body_label = df[['sender', 'receiver', 'date', 'subject', 'body']].copy()
data_table.DataTable(df_header_body_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Define your full target path
submission_folder = path
gpt_llm_path = os.path.join(submission_folder,'001 Submission','All APIs',  'gpt_llm', 'prompt_data','All_data')

# Create the directory structure
os.makedirs(gpt_llm_path, exist_ok=True)

# Save the 3 labeled DataFrames to the new location

# 1. Header with label
df_header_label.to_csv(os.path.join(gpt_llm_path, 'header_without_label.csv'), index=False)

# 2. Body with label
df_body_label.to_csv(os.path.join(gpt_llm_path, 'body_without_label.csv'), index=False)

# 3. Combined Header + Body with label
df_header_body_label.to_csv(os.path.join(gpt_llm_path, 'header_body_without_label.csv'), index=False)

print(f"✅ All files saved successfully to: {gpt_llm_path}")
# Out:
# ✅ All files saved successfully to: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/prompt_data/All_data

# %% [markdown]
# ## create sample 75 rows

# %% [markdown]
# ### 75 Data with labels

# %%
#  Define input and output folder paths
input_path =  os.path.join(path,'001 Submission','All APIs',  'gpt_llm', 'raw_data','Data_with_label')
#  '/content/drive/MyDrive/outPut_Folder/gpt_llm/raw_data/Data_with_label'
output_path = os.path.join(path,'001 Submission','All APIs',  'gpt_llm', 'raw_data','sample_75_with_labels')
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/raw_data/sample_75_with_labels'
os.makedirs(output_path, exist_ok=True)  # Create output folder if not exists

# Define filenames and new names for output
files_to_sample = {
    'header_with_label.csv': 'header_sample_75_with_label.csv',
    'body_with_label.csv': 'body_sample_75_with_label.csv',
    'header_body_with_label.csv': 'header_body_sample_75_with_label.csv'
}

#  Load each file, extract 75 rows, and save to new location
for input_file, output_file in files_to_sample.items():
    full_input_path = os.path.join(input_path, input_file)
    full_output_path = os.path.join(output_path, output_file)

    # Load the full file
    df = pd.read_csv(full_input_path)

    # Extract the first 75 rows
    df_sample = df.head(75)

    # Save to the new folder
    df_sample.to_csv(full_output_path, index=False)
    print(f"✅ Saved first 75 rows of {input_file} → {full_output_path}")
# Out:
# ✅ Saved first 75 rows of header_with_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/raw_data/sample_75_with_labels/header_sample_75_with_label.csv
# ✅ Saved first 75 rows of body_with_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/raw_data/sample_75_with_labels/body_sample_75_with_label.csv
# ✅ Saved first 75 rows of header_body_with_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/raw_data/sample_75_with_labels/header_body_sample_75_with_label.csv

# %% [markdown]
# ### 75 data without labels

# %%
#  Define input and output folder paths
input_path = os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'prompt_data','All_data')
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/All_data'
output_path = os.path.join(path,'001 Submission','All APIs',  'gpt_llm', 'prompt_data','sample_75_without_labels')
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels'
os.makedirs(output_path, exist_ok=True)  # Create output folder if not exists

#  Define filenames and new names for output
files_to_sample = {
    'header_without_label.csv': 'header_sample_75_without_label.csv',
    'body_without_label.csv': 'body_sample_75_without_label.csv',
    'header_body_without_label.csv': 'header_body_sample_75_without_label.csv'
}

# Load each file, extract 75 rows, and save to new location
for input_file, output_file in files_to_sample.items():
    full_input_path = os.path.join(input_path, input_file)
    full_output_path = os.path.join(output_path, output_file)

    # Load the full file
    df = pd.read_csv(full_input_path)

    # Extract the first 75 rows
    df_sample = df.head(75)

    # Save to the new folder
    df_sample.to_csv(full_output_path, index=False)
    print(f"✅ Saved first 75 rows of {input_file} → {full_output_path}")
# Out:
# ✅ Saved first 75 rows of header_without_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/prompt_data/sample_75_without_labels/header_sample_75_without_label.csv
# ✅ Saved first 75 rows of body_without_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/prompt_data/sample_75_without_labels/body_sample_75_without_label.csv
# ✅ Saved first 75 rows of header_body_without_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/prompt_data/sample_75_without_labels/header_body_sample_75_without_label.csv

# %% [markdown]
# ### printing the dataset

# %%
# Load header sample
df_header_sample = pd.read_csv(os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'prompt_data','sample_75_without_labels','header_sample_75_without_label.csv'))
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/header_sample_75_without_label.csv

# Load body sample
df_body_sample = pd.read_csv(os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'prompt_data','sample_75_without_labels','body_sample_75_without_label.csv'))
                            #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/body_sample_75_without_label.csv'

# Load combined header+body sample
df_combined_sample = pd.read_csv(os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'prompt_data','sample_75_without_labels','header_body_sample_75_without_label.csv'))
                                #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/header_body_sample_75_without_label.csv'

# %%
df_header_sample.head(10)
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                 Michael Parker <ivqrnai@pobox.com>
# 4  Gretchen Suggs <externalsep1@loanofficertool.com>
# 5  Caroline Aragon <dwthaidomainnamesm@thaidomain...
# 6    Replica Watches <jhorton@thebakercompanies.com>
# 7             Daily Top 10 <acidirev_1972@tcwpg.com>
# 8                  qydlqcws-iacfym@issues.apache.org
# 9      Daily Top 10 <orn|dent_1973@musicaedischi.it>
#
#                                          receiver  \
# 0                     user4@gvc.ceas-challenge.cc
# 1                   user2.2@gvc.ceas-challenge.cc
# 2                   user2.9@gvc.ceas-challenge.cc
# 3  SpamAssassin Dev <xrh@spamassassin.apache.org>
# 4                   user2.2@gvc.ceas-challenge.cc
# 5                user7-ext5@gvc.ceas-challenge.cc
# 6                  user2.10@gvc.ceas-challenge.cc
# 7                   user2.3@gvc.ceas-challenge.cc
# 8                     xrh@spamassassin.apache.org
# 9                     user7@gvc.ceas-challenge.cc
#
#                               date  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700
# 1  Tue, 05 Aug 2008 18:31:03 -0500
# 2  Tue, 05 Aug 2008 20:28:00 -1200
# 3  Tue, 05 Aug 2008 17:31:20 -0600
# 4  Tue, 05 Aug 2008 19:31:21 -0400
# 5  Wed, 06 Aug 2008 05:31:22 +0600
# 6  Tue, 05 Aug 2008 21:44:01 +0000
# 7  Tue, 05 Aug 2008 20:41:14 -0300
# 8  Tue, 05 Aug 2008 15:31:03 -0800
# 9  Wed, 06 Aug 2008 00:31:38 +0100
#
#                                              subject
# 0                          Never agree to be a loser
# 1                             Befriend Jenna Jameson
# 2                               CNN.com Daily Top 10
# 3  Re: svn commit: r619753 - in /spamassassin/tru...
# 4                         SpecialPricesPharmMoreinfo
# 5                               From Caroline Aragon
# 6                                    Replica Watches
# 7                               CNN.com Daily Top 10
# 8  [Bug 5780] URI processing turns uuencoded stri...
# 9                               CNN.com Daily Top 10

# %%
df_body_sample.head(50)
# Out:
#                                                  body
# 0   Buck up, your troubles caused by small dimensi...
# 1   \nUpgrade your sex and pleasures with these te...
# 2   >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 3   Would anyone object to removing .so from this ...
# 4   \nWelcomeFastShippingCustomerSupport\nhttp://7...
# 5   \n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...
# 6   We have fake Swiss Men's and Ladie's Replica \...
# 7   >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 8   http://issues.apache.org/SpamAssassin/show_bug...
# 9   >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 10  \nDo Not consolidate your debt   Eliminate it!...
# 11  \nAdobe Creative Suite 3 Master Collection for...
# 12  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 13  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 14  \nexpressherbals\n \nhttp://pacelike.com\n \nF...
# 15  \nPlelim,\n\nJust to remind you that if a cert...
# 16  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 17  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 18  Carlos E. R. wrote: > -----BEGIN PGP SIGNED ME...
# 19  Steve Jacobs wrote: > ---------- Forwarded mes...
# 20  \n\n\nScienceNOW Week in Review\n\n\n\n\n\n\n\...
# 21  # New Ticket Created by  Zefram \n# Please inc...
# 22  Send Wekalist mailing list submissions to\n\ti...
# 23  Update of /cvsroot/spambayes/spambayes/spambay...
# 24  Greg Freemyer wrote:\n> All,\n> \n> I'm runnin...
# 25  #PjWmcUDemi Moore Full video without cowards.\...
# 26  Britney spears p0rn video, Jennifer Lopez pict...
# 27  Benji Weber wrote:\n> On 07/02/2008, Mike  wro...
# 28  The secret to unlocking women�s G-spots http:/...
# 29  Bacheelor, MasteerMBA, and Doctoraate diplomas...
# 30  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 31  \n\n\nLargest selection of medication products...
# 32  Usage of this formula accounts for many great ...
# 33  demerphq  wrote:\n:Nobull (Brian McCauly) repo...
# 34  Good morning all,\n\nA customer is looking for...
# 35  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 36  \nUpgrade your sex and pleasures with these te...
# 37           \t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDoctors...
# 38  http://issues.apache.org/SpamAssassin/show_bug...
# 39  Become more courageous in your romantic relati...
# 40  \n\n\n\n\n\n\n         Make  a present to some...
# 41  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 42  \nnetwork curl bearberry? aromatic, imaginate ...
# 43  Hello\n\nI have just compiled crm114, there wa...
# 44  \n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n      Aug. 5,...
# 45  Sloan wrote:\n> Wolfgang Woehl wrote:\n>> Aaro...
# 46  \n\n\n\n\n\nSee a schlub like me get lucky in ...
# 47  \n\n\n \n\n\n\n\n \n\n\n\n\n\n\n\n\n\nAUG. 05,...
# 48  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 49  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...

# %%
df_combined_sample.head(2)
# Out:
#                              sender                       receiver  \
# 0  Young Esposito <Young@iworld.de>    user4@gvc.ceas-challenge.cc
# 1      Mok <ipline's1983@icable.ph>  user2.2@gvc.ceas-challenge.cc
#
#                               date                    subject  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700  Never agree to be a loser
# 1  Tue, 05 Aug 2008 18:31:03 -0500     Befriend Jenna Jameson
#
#                                                 body
# 0  Buck up, your troubles caused by small dimensi...
# 1  \nUpgrade your sex and pleasures with these te...

# %% [markdown]
# # prompting

# %% [markdown]
# ## Zeroshot

# %%
def create_zeroshot_prompt(row, email_type="header"):

    if email_type == "header":
        return f"""
Classify this email header as 'Phishing' or 'Legitimate'. Then briefly explain why.

Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}

Format: Phishing or Legitimate|Reason
"""

    elif email_type == "body":
        return f"""
Classify this email body as 'Phishing' or 'Legitimate'. Then briefly explain why.

Body: {row['body']}

Format: Phishing or Legitimate|Reason
"""

    elif email_type == "combined":
        return f"""
Classify this email (header and body) as 'Phishing' or 'Legitimate'. Then briefly explain why.

Header:
Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}

Body:
{row['body']}

Format: Phishing or Legitimate|Reason
"""

    else:
        raise ValueError(" Invalid email_type specified.")

# %%
# Sends a single prompt to GPT-4o and returns safe Prediction & Reason
def analyze_email_with_gpt(prompt):
    try:
        #  Send prompt to GPT-4o-mini chat API
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are a cybersecurity expert classifying emails."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.2
        )

        # Extract the raw GPT reply string
        reply = response.choices[0].message.content.strip()
        print(reply)


        #  spliting the reply with '|'
        parts = reply.split("|")

        # FIX for ValueError #1: If only 1 part, add  reason
        if len(parts) == 1:
            parts.append("No explanation provided.")

        # FIX for ValueError #2: If more than 2 parts, merge extras as one reason
        elif len(parts) > 2:
            parts = [parts[0], "|".join(parts[1:])]

        # Always return exactly two clean strings
        return pd.Series([p.strip() for p in parts])

    except Exception as e:
        #FIX for ValueError #3: Catch API/logic errors, return two parts
        return pd.Series(["Error", str(e)])

# %%
# Processes a CSV file from sample_75 and saves predictions to a new Excel file in output_data
def process_sample_75_csv_to_output(file_name, email_type):
    # Construct full path to input CSV file
    input_path = os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'prompt_data','sample_75_without_labels',file_name)
        # input_path = f'/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/{file_name}'
    # Define output folder location
    output_folder = os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'output_daata','zeroshot')
    #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/output_daata/zeroshot'
    os.makedirs(output_folder, exist_ok=True)

    # Construct output filename by replacing '.csv' with '_predicted.xlsx'
    output_file = file_name.replace('.csv', '_predicted.xlsx')
    output_path = os.path.join(output_folder, output_file)

    #  Load the CSV input into a pandas DataFrame
    df = pd.read_csv(input_path)


    #  Apply GPT to each row using zero-shot prompt
    df[['Prediction', 'Reason']] = df.apply(
        lambda row: analyze_email_with_gpt(create_zeroshot_prompt(row, email_type)),
        axis=1
    )

    # Convert predictions to numeric labels
    df["prediction_label"] = df["Prediction"].map(lambda x: 1 if x.strip().lower() == "phishing" else 0)

    # Reorder prediction_label column right after Prediction
    cols = df.columns.tolist()
    if "Prediction" in cols and "Reason" in cols and "prediction_label" in cols:
        pred_idx = cols.index("Prediction")
        cols.insert(pred_idx + 1, cols.pop(cols.index("prediction_label")))
        df = df[cols]

    #  Save the final DataFrame as Excel file
    df.to_excel(output_path, index=False)
    print(f"✅ Processed: {file_name} → Saved to {output_path}")

# %% [markdown]
# ## Fewshot

# %%
# Pre-defined examples (few-shot) to "teach" the model before each real classification
FEW_SHOT_EXAMPLES = {
    "header": [
        {
            "sender": "admin@securebank.com",
            "receiver": "user123@gmail.com",
            "subject": "Important Account Notification",
            "date": "2024-11-05",
            "label": "Phishing",
            "reason": "The sender's email is suspicious and urges action."
        },
        {
            "sender": "newsletter@trustedsource.com",
            "receiver": "user123@gmail.com",
            "subject": "Monthly Newsletter - November",
            "date": "2024-11-01",
            "label": "Legitimate",
            "reason": "It’s a regular newsletter from a known sender."
        }
    ],
    "body": [
        {
            "body": "Your account has been locked. Click here to verify immediately: http://scam-site.com",
            "label": "Phishing",
            "reason": "Urgent tone and suspicious link included."
        },
        {
            "body": "Here is your delivery confirmation for order #12345. Thank you for shopping with us!",
            "label": "Legitimate",
            "reason": "Normal e-commerce confirmation message."
        }
    ],
    "combined": [
        {
            "sender": "alerts@paypal-security.com",
            "receiver": "user@gmail.com",
            "subject": "Verify your PayPal account now!",
            "date": "2024-11-08",
            "body": "We noticed suspicious activity. Click below to confirm.",
            "label": "Phishing",
            "reason": "Suspicious sender and urgent call-to-action."
        },
        {
            "sender": "support@github.com",
            "receiver": "user@gmail.com",
            "subject": "New login detected",
            "date": "2024-11-01",
            "body": "We noticed a new login from a different location. If this was you, no further action is required.",
            "label": "Legitimate",
            "reason": "Clear explanation, no suspicious links, from a known service."
        }
    ]
}

# %%
def create_few_shot_prompt(row, email_type="header"):
    examples = FEW_SHOT_EXAMPLES[email_type]
    prompt = "You are an email security classifier. Learn from the examples below.\n\n"

    # Add compact few-shot examples
    for ex in examples:
        if email_type == "header":
            prompt += (
                f"Sender: {ex['sender']}, Subject: {ex['subject']}, Date: {ex['date']}\n"
                f"Answer: {ex['label']} | {ex['reason']}\n\n"
            )
        elif email_type == "body":
            prompt += (
                f"Body: {ex['body']}\n"
                f"Answer: {ex['label']} | {ex['reason']}\n\n"
            )
        elif email_type == "combined":
            prompt += (
                f"Sender: {ex['sender']}, Subject: {ex['subject']}, Date: {ex['date']}, Body: {ex['body']}\n"
                f"Answer: {ex['label']} | {ex['reason']}\n\n"
            )

    # Now add the row to classify
    if email_type == "header":
        prompt += (
            f"Sender: {row['sender']}, Subject: {row['subject']}, Date: {row['date']}\n"
            f"Answer:"
        )
    elif email_type == "body":
        prompt += (
            f"Body: {row['body']}\n"
            f"Answer:"
        )
    elif email_type == "combined":
        prompt += (
            f"Sender: {row['sender']}, Subject: {row['subject']}, Date: {row['date']}, Body: {row['body']}\n"
            f"Answer:"
        )

    return prompt

# %%
def analyze_email_few_shot(prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are a cybersecurity expert trained to detect phishing emails."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.2
        )
        reply = response.choices[0].message.content.strip()
        print(reply)
        return pd.Series(reply.split("|"))  # Returns ["Prediction", "Reason"]
    except Exception as e:
        return pd.Series(["Error", str(e)])

# %%
def process_sample_75_few_shot(file_name, email_type):
    input_path = os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'prompt_data','sample_75_without_labels',file_name)
    # f'/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/{file_name}'
    output_folder = os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'output_daata','fewshot')
    #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/output_daata/fewshot'
    os.makedirs(output_folder, exist_ok=True)

    output_file = file_name.replace('.csv', '_fewshot_predicted.xlsx')
    output_path = os.path.join(output_folder, output_file)

    # Load input data
    df = pd.read_csv(input_path)

    # Apply GPT to each row using few-shot prompt
    df[['Prediction', 'Reason']] = df.apply(
        lambda row: analyze_email_few_shot(create_few_shot_prompt(row, email_type)),
        axis=1
    )

    # Convert textual label to numeric
    df["prediction_label"] = df["Prediction"].map(lambda x: 1 if x.strip().lower() == "phishing" else 0)

    # Reorder prediction_label
    cols = df.columns.tolist()
    if "Prediction" in cols and "Reason" in cols and "prediction_label" in cols:
        pred_idx = cols.index("Prediction")
        cols.insert(pred_idx + 1, cols.pop(cols.index("prediction_label")))
        df = df[cols]

    # Save to Excel
    df.to_excel(output_path, index=False)
    print(f"✅ Few-shot processed and saved → {output_path}")

# %% [markdown]
# ## Chain of thought

# %%
def analyze_email_chain_of_thought(prompt):

    try:
        # Send the prompt to GPT-4o for classification using chat completion
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You're a cybersecurity expert using step-by-step reasoning."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.2  # Lower temperature = more consistent classification
        )

        # Response from the gpt model
        reply = response.choices[0].message.content.strip()
        print(reply)

        # We split the response assuming format: "Prediction | Reason"
        parts = reply.split("|")

        # Example: Model replies with just "Phishing"
        if len(parts) == 1:
            parts.append("")  # Add empty string as Reason

        # Example: "Phishing | Urgent content | Suspicious link" → join extra parts into Reason
        elif len(parts) > 2:
            parts = [parts[0], "|".join(parts[1:])]

        # ✅ Clean up each part by stripping whitespace
        return pd.Series([p.strip() for p in parts])  # Always returns exactly two elements

    except Exception as e:
        # If GPT call fails, return error message for logging or review
        return pd.Series(["Error", str(e)])

# %%
def create_chain_of_thought_prompt(row, email_type="header"):

    if email_type == "header":
        return f"""
You are a cybersecurity expert. Decide if this email header is phishing or legitimate.

Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}

Answer format: Legitimate or Phishing | Brief Reason
"""

    elif email_type == "body":
        return f"""
You are a cybersecurity expert. Decide if this email body is phishing or legitimate.

Body: {row['body']}

Answer format: Legitimate or Phishing | Brief Reason
"""

    elif email_type == "combined":
        return f"""
You're a cybersecurity analyst. Decide if this full email is phishing or legitimate.


Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}
Body: {row['body']}

Answer format: Legitimate or Phishing | Brief Reason
"""

    else:
        raise ValueError(" Invalid email_type passed to prompt generator.")

# %%
# ✅ Loads a sample_75 CSV file, applies CoT prompting, and saves results as Excel
def process_chain_of_thought(file_name, email_type="header"):
    #  Define paths
    input_path = os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'prompt_data','sample_75_without_labels',file_name)
    #  f'/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/{file_name}'
    output_folder = os.path.join(path,'001 Submission','All APIs', 'gpt_llm', 'output_daata','chainofthought')
    #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/output_daata/chainofthought'
    os.makedirs(output_folder, exist_ok=True)

    output_file = file_name.replace('.csv', '_cot_predicted.xlsx')
    output_path = os.path.join(output_folder, output_file)

    # Load input CSV into DataFrame
    df = pd.read_csv(input_path)

    #  Generate CoT prompt per email and apply GPT-4o
    df[['Prediction', 'Reason']] = df.apply(
        lambda row: analyze_email_chain_of_thought(create_chain_of_thought_prompt(row, email_type)),
        axis=1
    )

    # Map textual prediction to numeric label (1 = phishing, 0 = legitimate)
    df["prediction_label"] = df["Prediction"].apply(
        lambda x: 1 if isinstance(x, str) and "phishing" in x.lower() else 0
    )

    #  Reorder columns (optional)
    cols = df.columns.tolist()
    if "Prediction" in cols and "Reason" in cols and "prediction_label" in cols:
        pred_idx = cols.index("Prediction")
        cols.insert(pred_idx + 1, cols.pop(cols.index("prediction_label")))
        df = df[cols]

    # 🔹 Save final DataFrame as Excel
    df.to_excel(output_path, index=False)

    # ✅ Confirm completion
    print(f"✅ CoT analysis complete for '{email_type}' emails. File saved at: {output_path}")

# %% [markdown]
# # Zero shot analysis

# %%
process_sample_75_csv_to_output("header_sample_75_without_label.csv", "header")
process_sample_75_csv_to_output("body_sample_75_without_label.csv", "body")
process_sample_75_csv_to_output("header_body_sample_75_without_label.csv", "combined")
# Out:
# Phishing|The email's subject line "Never agree to be a loser" is suspicious and potentially manipulative, which is a common tactic in phishing attempts. Additionally, the sender's email domain "iworld.de" does not provide any clear connection to the receiver's domain, raising further suspicion about the email's legitimacy.
# Phishing|The email header contains several red flags: the sender's email address is suspicious and does not match any known legitimate domain, the subject line is unusual and potentially enticing in a way that is common in phishing attempts, and the date is significantly outdated, which could indicate a recycled or spoofed email.
# Phishing|The email header shows a suspicious sender address that does not match the purported sender (CNN.com). The domain "universalnet.psi.br" is unrelated to CNN, which is a common tactic used in phishing to deceive recipients. Additionally, the date format and time zone (-1200) are unusual, which can be indicative of a phishing attempt.
# Phishing|The email header contains a suspicious sender email address (ivqrnai@pobox.com) that does not match the typical format or domain of a legitimate sender. Additionally, the subject line references a specific technical commit, which could be used to lure recipients into believing it is a legitimate communication related to software development, a common tactic in phishing attempts.
# Phishing|The email header contains several red flags: the sender's email address is from a suspicious domain (loanofficertool.com) that does not match the subject of the email, which is related to pharmaceuticals. The subject line "SpecialPricesPharmMoreinfo" is vague and indicative of spam or phishing attempts. Additionally, the use of an external domain and the mismatch between the sender's domain and the email content suggest a potential phishing attempt.
# Phishing|The email header contains several red flags: the sender's email address appears suspicious and unrelated to the purported sender's name, the domain name seems unusual and potentially misleading, and the subject line is vague and lacks context. Additionally, the email is dated from 2008, which could indicate an attempt to use outdated or compromised data.
# Phishing|The email is likely phishing because it is promoting replica watches, which is a common subject in spam and phishing emails. Additionally, the sender's email address does not match the subject matter, suggesting it may be spoofed or compromised.
# Phishing|The email is suspicious due to the sender's email address, which does not match the official domain of CNN or any recognizable entity. Additionally, the email is dated from 2008, which is unusual and could indicate an attempt to bypass filters by using outdated information.
# Legitimate|Reason: The email appears to be a bug report or discussion related to the Apache SpamAssassin project, indicated by the sender and receiver addresses being associated with the Apache organization. The subject line references a specific bug number, which is typical for legitimate bug tracking and issue discussions. Additionally, the use of a mailing list format and the technical nature of the subject matter suggest it is a legitimate communication.
# Phishing|The email is suspicious due to the mismatch between the sender's name "Daily Top 10" and the email address "orn|dent_1973@musicaedischi.it," which does not align with a legitimate CNN domain. Additionally, the use of a non-CNN domain and the unusual format of the email address suggest it could be a phishing attempt.
# Phishing|The email is likely phishing due to the generic and suspicious subject line "debt consolidation," which is a common topic used in phishing scams. Additionally, the sender's email address appears to be a random string of characters, which is often a sign of a spoofed or compromised account. The domain "flychautauqua.com" does not seem relevant to the subject matter, adding to the suspicion.
# Phishing|The email header shows signs of phishing: the sender's email address appears suspicious and unrelated to the subject matter, the subject line is vague and potentially misleading, and the date is from 2008, which is unusually old for a legitimate email. Additionally, the domain "gametea.com" does not match the content of the email, suggesting it could be an attempt to deceive the recipient.
# Phishing|The email header shows a suspicious sender address that does not match the purported sender (CNN.com). The domain "weijgers.nl" does not relate to CNN, which is a common tactic in phishing to impersonate reputable sources. Additionally, the email is dated from 2008, which could indicate an attempt to use outdated or compromised data.
# Phishing|The email is suspicious due to the mismatch between the sender's name "Daily Top 10" and the email address "Scooter-obailat@picklesmaternity.com," which does not align with a reputable news source like CNN. Additionally, the domain "picklesmaternity.com" is unrelated to news content, suggesting a potential phishing attempt.
# Phishing|The email header contains several red flags: the sender's email address appears suspicious and unrelated to any known legitimate organization, the subject line is vague and lacks context, and the date is unusually old, which may indicate an attempt to bypass spam filters by using outdated information. Additionally, the domain in the receiver's email address seems unusual and not commonly associated with legitimate communications.
# Phishing|The email header shows a mismatch between the sender's name "Racing" and the email domain "sailing.ie," which is suspicious. Additionally, the subject line "RE: Trial IRC Certificate Application" could be an attempt to create urgency or legitimacy, a common tactic in phishing emails. The date is also quite old, which could indicate an attempt to use outdated information to deceive the recipient.
# Phishing|The email is suspicious due to the mismatch between the sender's name "Daily Top 10" and the email address domain "picklesmaternity.com," which is unrelated to CNN. Additionally, the use of a seemingly random and unrelated domain suggests an attempt to deceive the recipient.
# Phishing|The email is suspicious due to the sender's email address, which does not match the purported sender (Daily Top 10) and uses a domain (picklesmaternity.com) unrelated to CNN. Additionally, the email is sent to a generic or unusual receiver address, which is often a tactic used in phishing attempts.
# Legitimate|Reason: The email header indicates a discussion on a technical topic related to the OpenSUSE mailing list, which is a legitimate use case. The sender's email address, while not from a corporate domain, does not inherently suggest phishing, especially in the context of a mailing list where personal email addresses are common. Additionally, the subject line and recipient align with a typical technical support query, further supporting its legitimacy.
# Phishing|Reason: The email header contains several red flags indicative of phishing. The sender's email address appears suspicious and does not match a legitimate or recognizable domain, which is often a tactic used in phishing to disguise the sender's identity. Additionally, the subject line includes multiple "Re:" and "Fwd:" prefixes, which can be a tactic to make the email appear as part of an ongoing conversation and to bypass spam filters. The date of the email is also quite old, which could be an attempt to make the email seem like a legitimate archived conversation.
# Legitimate|The email header appears to be from a legitimate source, as "aaas-alerts.org" is associated with the American Association for the Advancement of Science (AAAS), which sends out ScienceNOW alerts. The subject and format are consistent with a legitimate newsletter or alert service.
# Legitimate|Reason: The email appears to be a legitimate bug report or discussion related to Perl programming, indicated by the subject line referencing a specific Perl issue number and the sender's and receiver's email addresses being associated with Perl and development domains. There are no typical phishing indicators such as urgent requests, suspicious links, or attachments.
# Legitimate|The email header indicates it is from a mailing list (list.scms.waikato.ac.nz) associated with Waikato, which is a known educational institution. The subject line suggests it is a digest from a listserv, which is a common format for legitimate mailing lists. There are no obvious signs of phishing such as suspicious sender addresses, urgent language, or requests for personal information.
# Legitimate|Reason: The email header indicates a message related to a source code repository check-in, which is typical for open-source projects. The sender's email address is associated with SourceForge, a well-known platform for open-source software development. The subject line suggests a version control update, and the receiver's address is linked to Python.org, which is consistent with the context of open-source development and collaboration. There are no typical phishing indicators such as suspicious links, urgent requests for personal information, or mismatched sender information.
# Legitimate|Reason: The email header appears to be part of a mailing list discussion related to OpenSUSE, a Linux distribution. The subject line indicates a technical issue/question, which is typical for such forums. The sender's email address, while not a corporate domain, is not uncommon for personal or open-source community communications. There are no immediate red flags such as urgent language, suspicious links, or requests for sensitive information that are typical of phishing attempts.
# Phishing|The email subject ";) Look porno Gallery!!!" is suspicious and indicative of a phishing attempt. The use of inappropriate and attention-grabbing language is a common tactic in phishing emails to entice recipients to open the email or click on malicious links. Additionally, the sender's email address does not match the content of the subject, further suggesting it is not legitimate.
# Phishing|The email is suspicious due to the generic subject "Your order" without specific details, and the sender's email domain "goline.ca" does not match any known reputable company. Additionally, the use of an external domain for the receiver "gvc.ceas-challenge.cc" suggests it might be part of a phishing test or challenge, which is often used to simulate phishing scenarios.
# Phishing|The email header raises suspicion due to the sender's email address, which appears to be randomly generated and uses a free email service (hotpop.com), often associated with phishing attempts. Additionally, the subject line referencing an outdated version of OpenSuse (11) from 2008 could indicate an attempt to exploit older, potentially vulnerable systems.
# Phishing|The email is suspicious due to the unusual sender address that appears to be from an educational institution, which is unlikely to be associated with promoting herbal products. Additionally, the subject line is vague and unrelated to the sender's domain, which is a common tactic used in phishing attempts to lure recipients into opening the email.
# Phishing|The email header contains several red flags: the sender's email address does not match the name, suggesting it may be spoofed; the subject line is suspicious and contains a typo ("Degreees"), which is common in phishing attempts to bypass spam filters; and the date is from 2008, which is unusual for a legitimate email in 2023, indicating it might be part of a phishing campaign using old data.
# Phishing|The email is suspicious due to the sender's email address, which does not match the legitimate domain of CNN. Additionally, the domain "4000down.com" is unrelated to CNN, and the email could be attempting to impersonate a trusted source to deceive the recipient.
# Phishing|The email header appears suspicious due to the mismatch between the sender's email domain (cityofws.org) and the subject line ("Man's stuff store"), which suggests a commercial intent not typically associated with a government or official city domain. Additionally, the email is dated 2008, which could indicate an attempt to use outdated or compromised email accounts for phishing purposes.
# Phishing|The email subject "Change your weakness to power" is vague and potentially manipulative, which is a common tactic in phishing emails. Additionally, the email is from 2008, which could indicate it is part of an old phishing campaign. The sender's domain "archie.dk" does not clearly relate to the receiver's domain, which could be suspicious.
# Legitimate|Reason: The email header appears to be part of a technical discussion about a regex issue, which is a common topic among developers. The sender's email address uses a domain that could plausibly be related to technical or cryptographic discussions. There are no typical phishing indicators such as urgent requests, suspicious links, or attachments. Additionally, the date is from 2008, which suggests it may be part of an archived or historical conversation rather than a phishing attempt.
# Legitimate|The email header appears to be legitimate as it includes a specific sender and receiver with domain names that match the context of a book-related inquiry. The subject line is not suspicious, and the date is consistent with typical email communication. There are no immediate red flags such as suspicious email addresses, urgent language, or unusual requests that are common in phishing attempts.
# Phishing|The sender's email address appears suspicious with a random string and a domain that does not match the purported sender (CNN). Additionally, the use of a generic subject line like "CNN.com Daily Top 10" is often used in phishing attempts to lure recipients into opening the email.
# Phishing|The email subject is suspicious and potentially inappropriate, which is a common tactic used in phishing to entice users to open the email. Additionally, the sender's email address is missing, which is unusual for legitimate communications.
# Phishing|The subject line "Touch her heart with your new babymaker" is suspicious and indicative of spam or phishing attempts. It uses inappropriate and suggestive language that is often associated with scams. Additionally, the sender's email address appears to be from a domain that doesn't match any known legitimate organization, and the email is sent to an unusual receiver address format, which is often used in phishing campaigns.
# Legitimate|The email appears to be from a legitimate Apache domain (issues.apache.org) and is related to a bug review, which is typical for developer or project communication. The subject line is technical and specific, consistent with genuine project discussions rather than phishing attempts.
# Phishing|The email subject "Mega-huge dimension for you!" is vague and sensational, which is a common tactic used in phishing emails to entice recipients to open the email. Additionally, the sender's email domain "allianz.pt" does not match the typical domain for Allianz, a well-known insurance company, which usually uses "allianz.com" or a similar domain. The email is also sent to a generic and unusual receiver address, which is often used in phishing attempts.
# Phishing|The email is likely phishing due to the suspicious sender's email address, which does not match the subject matter. The subject line is unrelated to any known business or personal communication, and the email is sent from a generic and potentially compromised domain (tiscali.it). Additionally, the email is sent to a challenge domain (ceas-challenge.cc), which is often used for testing and research purposes, indicating it may be part of a phishing test or campaign.
# Phishing|The email is suspicious due to the mismatch between the sender's name "Daily Top 10" and the email address domain "victoriaco.com," which does not appear to be associated with CNN. Additionally, the use of a generic subject line like "CNN.com Daily Top 10" without any personalized content or context is a common tactic in phishing attempts.
# Phishing|The email header contains a suspicious and nonsensical subject line, which is a common tactic in phishing attempts to bypass spam filters. Additionally, the sender's email address appears to be from a domain (defamer.com) that does not match the subject or any legitimate business context, further indicating potential phishing.
# Phishing|The email header contains several red flags indicative of phishing: the sender's email address appears suspicious and does not match the name provided, suggesting potential spoofing. Additionally, the use of a public email domain (gmx.de) for what seems to be a professional announcement is unusual. The subject line is vague and could be attempting to lure recipients into opening the email without providing specific details.
# Legitimate|The email appears to be from a reputable source, Winnipeg Free Press, and is consistent with a news alert service. The sender's email address matches the domain of the organization, and there are no immediate red flags such as suspicious links or requests for personal information.
# Phishing|The email is suspicious due to the sender's email address, which appears to be a randomly generated string and uses a free email service (hotpop.com). This is a common tactic in phishing attempts to disguise the sender's true identity. Additionally, the subject line is vague and could be attempting to exploit a known topic or group (OpenSuse) to gain trust.
# Phishing|The email is likely phishing due to the suspicious and unsolicited subject line related to erectile dysfunction, which is a common topic used in spam and phishing emails. Additionally, the sender's name is vague and lacks a proper email address, which is a common tactic used in phishing attempts to obscure the sender's identity.
# Legitimate|The email header shows a sender address from a legitimate domain "nbclocal.com," which is associated with NBC. The subject and sender information do not exhibit typical phishing characteristics such as misspellings, suspicious links, or urgent calls to action. Additionally, the receiver's address appears to be part of a challenge or test environment, suggesting this is a controlled scenario rather than a phishing attempt.
# Phishing|Reason: The sender's email address (ranewc_1999@kamis.pl) does not match the expected domain for CNN, which should be something like cnn.com. Additionally, the use of a generic subject line like "CNN.com Daily Top 10" can be a tactic to lure recipients into opening the email. The mismatch between the sender's address and the purported content suggests a phishing attempt.
# Phishing|The email is suspicious because it uses a generic sender name "Daily Top 10" and an unusual sender email domain "jasonjones.com" that does not match the purported source "CNN.com". Additionally, the email is dated from 2008, which is outdated and could indicate a recycled or spoofed email.
# Legitimate|Reason: The email header appears to be from a legitimate academic source, as it involves a sender from the University of Waterloo and a receiver from Stanford University. The subject references a specific event, "CEAS 2007 Live Spam Challenge," which aligns with academic or research-related communication. The email date is also consistent with the subject matter, suggesting it is not a recent phishing attempt.
# Legitimate|Reason: The email header appears to be part of a mailing list discussion related to OpenSUSE, a Linux distribution. The subject line indicates a technical issue/question, which is common in legitimate technical mailing lists. The sender's email address, while using a free email service, does not inherently indicate phishing, especially in the context of a technical discussion from 2008.
# Phishing|The email is suspicious due to the sender's email address, which appears to be randomly generated and uses a free email service (hotpop.com). This is often a tactic used in phishing attempts to disguise the sender's identity. Additionally, the subject line suggests a reply to a community topic, which could be a tactic to gain the receiver's trust.
# Legitimate|Reason: The email header appears to be related to a bug report or review concerning a technical issue with a specific file (PerMsgStatus.pm) in a software project. The sender and receiver addresses are associated with the Apache Software Foundation, and the subject line indicates a discussion about a bug, which is common in open-source project communications. Additionally, the use of a mailing list format ([Bug 5813]) is typical for legitimate technical discussions within development communities.
# Legitimate|Reason: The email appears to be a job listing from a legitimate source, "Perl Jobs," which is consistent with the subject matter. The sender and receiver both have email addresses associated with "perl.org," a known domain related to the Perl programming community. There are no immediate red flags such as suspicious links, requests for personal information, or mismatched domains that are typical indicators of phishing emails. Additionally, the email is dated from 2008, a time when phishing tactics were less sophisticated, and this format aligns with legitimate job listing communications from that period.
# Legitimate|The email header appears to be from a legitimate source related to Perl job postings. The sender's address is from a domain associated with Perl, and the subject line is consistent with job listings. There are no immediate red flags such as suspicious links, urgent requests for personal information, or mismatched sender and receiver domains that are typical in phishing emails.
# Legitimate|The email header appears to be from a known organization, Organic Consumers Association, using a legitimate mailing service domain (democracyinaction.org). The subject, while sensational, aligns with topics typically discussed by advocacy groups. There are no immediate red flags such as suspicious sender addresses or urgent requests for personal information.
# Legitimate|The email header appears to be from a legitimate source related to Perl job postings. The sender's address is from the domain "perl.org," which is consistent with the subject matter of the email. Additionally, the subject line is specific and relevant to job opportunities, which aligns with the sender's identity. There are no immediate red flags such as suspicious links or mismatched sender information.
# Phishing|The email header contains several red flags indicative of phishing: the sender's email address does not match the name "bradley dept," suggesting a potential spoofing attempt. The subject line is vague and includes a suspicious string of characters, which is often used to bypass spam filters. Additionally, the use of a generic and non-professional email domain (wxs.nl) further raises suspicion.
# Legitimate|Reason: The email header appears to be from a legitimate source, as it is sent from a domain associated with Perl (perl.org), which is a well-known programming language community. The subject line is consistent with job postings, and there are no immediate red flags such as suspicious links or requests for personal information. Additionally, the sender and receiver both have email addresses associated with perl.org, suggesting internal communication within a community or organization.
# Legitimate|Reason: The email header appears to be part of a mailing list discussion, indicated by the subject line prefix "[spambayes-dev]", which is a common convention for mailing lists. The sender's email address seems to be a legitimate domain, and there are no typical phishing indicators such as suspicious links, urgent requests, or mismatched sender information. Additionally, the date is from 2008, which suggests it is an archived or older email, typical for mailing list archives.
# Phishing|The email header contains several red flags indicative of phishing: the sender's name "harwilll jayanta" does not match the email address "dtkress@emdas.com," which is often a tactic used to deceive recipients. The subject line is vague and sensational, designed to entice the recipient to open the email. Additionally, the email is sent to a generic-looking address "user2.12@gvc.ceas-challenge.cc," which could be part of a bulk email list. These elements suggest an attempt to lure the recipient into a scam.
# Phishing|The email header contains several red flags typical of phishing attempts: the sender's email address appears suspicious and does not match a legitimate business domain, the subject line uses enticing language to lure the recipient, and the email is dated from 2008, which could indicate it is part of a recycled or outdated phishing campaign.
# Legitimate|Reason: The email header appears to be a legitimate inquiry sent to a mailing list related to R, a statistical programming language. The subject line is consistent with a technical question, and the sender's email address does not exhibit typical phishing characteristics such as suspicious domains or misspellings. Additionally, the receiver's address is a known mailing list for R-related discussions.
# Phishing|The email subject "Make your gf happy" is a common tactic used in phishing emails to entice recipients into opening the message. Additionally, the sender's email address appears suspicious and not associated with any known legitimate organization, which is often indicative of phishing attempts.
# Legitimate|The email header appears to be from a legitimate source related to Perl job postings. The sender's address is from the perl.org domain, which is associated with the Perl community. The subject line is consistent with a job posting, and there are no immediate red flags such as suspicious links or requests for personal information. Additionally, the date is from 2008, which suggests it is an older, possibly archived email, rather than a current phishing attempt.
# Phishing|The sender's name "andrzej janaki" does not match the email address "linda.groah@kp.org", which is suspicious. Additionally, the subject "Mego claybourne suggestion" is vague and does not provide any context, which is a common tactic in phishing emails to entice the recipient to open the email.
# Phishing|The email header shows a suspicious sender address with a subdomain (shag.dealerspace.com) that does not match the legitimate CNN domain. Additionally, the use of a generic name like "Daily Top 10" and the unusual domain structure suggest it could be an attempt to impersonate a trusted source.
# Phishing|The email is suspicious due to the generic and vague subject line "We offer you happiness," which is often used in phishing attempts to entice recipients. Additionally, the sender's email address does not match the domain of the organization they claim to represent, which is a common tactic in phishing to disguise the true origin of the email.
# Phishing|The sender's email address uses a suspicious domain (freemail.selfip.org) that does not match the legitimate domain of CNN. Additionally, the use of a generic and potentially misleading sender name "Daily Top 10" and the unusual domain suggests an attempt to impersonate a trusted source.
# Phishing|The sender's email address does not match the expected domain for CNN, which raises suspicion. Additionally, the use of a generic and unrelated domain (zamilsteel.com) suggests that this email may be attempting to impersonate a legitimate source.
# Phishing|The email header suggests phishing due to the suspicious subject line promoting a "prescription-free apothecary," which is a common tactic used in phishing to lure recipients into purchasing potentially illegal or unsafe products. Additionally, the sender's email address appears to be from a generic and potentially spoofed domain, which is another indicator of phishing.
# Phishing|The email header contains several red flags indicative of a phishing attempt: the subject line is promoting replica luxury watches, which is a common tactic used in spam and phishing emails. Additionally, the sender's email address does not match the content of the email, as "geneontology.org" is unrelated to selling watches. The use of a seemingly random and unrelated domain for the sender's email address is another common characteristic of phishing emails.
# Legitimate|Reason: The email appears to be a summary draft for a Python development mailing list, which is a common practice in open-source communities. The sender's email address, while using a generic Gmail domain, does not inherently indicate phishing, especially given the context of a mailing list. Additionally, the subject and date align with a typical mailing list summary, and there are no immediate red flags such as suspicious links or requests for sensitive information.
# Phishing|The sender's email address appears suspicious and is likely a randomly generated string, which is a common tactic in phishing attempts. The subject line "Splendid Health Joy" is vague and potentially misleading, often used to entice recipients to open the email. Additionally, the email is dated 2008, which is unusual and could indicate an attempt to bypass spam filters.
# ✅ Processed: header_sample_75_without_label.csv → Saved to /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/zeroshot/header_sample_75_without_label_predicted.xlsx
# Phishing|The email contains a suspicious link and uses language that is typically associated with spam or scams, such as promises of enhancing physical attributes. The content is irrelevant and disjointed, which is a common tactic in phishing emails to bypass spam filters.
# Phishing|Reason: The email contains a suspicious link and uses language that is often associated with spam or phishing attempts, aiming to lure recipients into clicking on the link for potentially malicious purposes.
# Legitimate|The email contains a structured format typical of a newsletter from a reputable news organization like CNN. It includes links to CNN's official website, a privacy policy, and an option to manage email preferences or unsubscribe, which are standard features of legitimate newsletters. Additionally, the content and formatting align with what one would expect from a professional news outlet.
# Legitimate|Reason: The email appears to be a discussion among developers or IT professionals regarding the handling of the .so top-level domain (TLD) within a software project, specifically related to SpamAssassin. The email includes technical details, references to code revisions, and legitimate URLs to Apache's SVN and Wikipedia, which are consistent with a professional and technical context. There are no requests for sensitive information or indications of malicious intent, which are typical characteristics of phishing emails.
# Phishing|The email contains a suspicious URL that does not match any known legitimate company domain and lacks any context or personalization, which are common indicators of phishing attempts.
# Phishing|The email body consists of a random sequence of characters and lacks coherent content or context, which is a common tactic in phishing attempts to bypass spam filters or confuse the recipient.
# Phishing|The email promotes counterfeit products, which is a common tactic used in phishing scams to lure recipients into clicking on links or providing personal information. Additionally, the use of terms like "fake" and "replica" suggests illegitimacy.
# Legitimate|The email contains structured content typical of a legitimate newsletter from CNN, including links to CNN's official website. The email also includes standard footer information such as the company's address, privacy guidelines, and options to manage email preferences or unsubscribe, which are common in legitimate communications.
# Legitimate|Reason: The email appears to be a notification from a bug tracking system, specifically from Apache's SpamAssassin project. It includes a URL to a legitimate Apache website and contains technical details related to bug tracking, which is typical for legitimate project management and issue tracking communications.
# Legitimate|The email appears to be a legitimate newsletter from CNN, containing links to CNN's official website and providing news stories and videos. The email includes proper branding, contact information, and links to manage preferences or unsubscribe, which are typical features of legitimate newsletters.
# Phishing|The email promises unrealistic outcomes such as eliminating debt without any negative consequences, which is a common tactic used in phishing scams to lure victims. The email also uses capital letters and urgent language to pressure the recipient, and it includes a suspicious link that could lead to a malicious website.
# Phishing|The email contains a suspicious link (http://oemmerchant.com) that does not appear to be an official Adobe website. This is a common tactic in phishing emails to lure recipients into clicking on potentially malicious links. Additionally, the email lacks personalization and context, which are typical characteristics of phishing attempts.
# Legitimate|The email contains a structured format typical of a legitimate newsletter from CNN, including links that appear to direct to CNN's official website. It also includes standard footer information such as the company's address, privacy policy, and unsubscribe options, which are common in legitimate corporate communications.
# Legitimate|The email contains a structured format typical of a newsletter from a reputable news organization like CNN. It includes links to CNN's official website, a clear unsubscribe link, and contact information for CNN, which are indicators of a legitimate email. Additionally, the content and layout are consistent with a typical news update email.
# Phishing|The email promotes unrealistic claims about physical enhancement, which is a common tactic used in phishing scams to lure individuals into clicking on potentially malicious links. The email lacks professional formatting, contains grammatical errors, and uses a suspicious URL, all of which are indicators of a phishing attempt.
# Legitimate|The email appears to be a genuine correspondence between individuals discussing the application process for a Trial IRC Certificate. It includes specific details such as contact information, addresses, and a website link that seems relevant to the context. Additionally, there are no requests for sensitive information or suspicious links, and the email has been screened for viruses and malicious code.
# Legitimate|The email appears to be a legitimate newsletter from CNN.com. It includes structured content typical of a news update, with links to CNN's website for further reading. The email contains proper branding, contact information, and privacy guidelines, which are consistent with legitimate corporate communications. Additionally, the unsubscribe link and preference management options are standard practices for legitimate newsletters.
# Legitimate|The email appears to be a legitimate newsletter from CNN, providing links to videos and stories on their website. The URLs are consistent with CNN's domain, and the email includes standard elements of a legitimate newsletter, such as unsubscribe options and privacy guidelines. Additionally, the email contains specific details like the sender's address and company information, which are typical of legitimate corporate communications.
# Legitimate|Reason: The email content appears to be a technical discussion among users of the TuxOnIce mailing list, focusing on issues related to hibernation and specific drivers. The email includes technical jargon, version numbers, and references to specific bugs and patches, which are typical of legitimate technical discussions. There are no requests for sensitive information, no suspicious links, and no signs of social engineering tactics commonly found in phishing emails.
# Legitimate|Reason: The email appears to be a legitimate discussion from a mailing list related to the Weka machine learning workbench. It includes technical discussions about software issues, installation problems, and algorithm explanations, which are typical topics for such lists. There are no requests for personal information, no suspicious links or attachments, and no urgent or threatening language, which are common indicators of phishing emails.
# Legitimate|Reason: The email appears to be a newsletter from ScienceNOW, a reputable source associated with the American Association for the Advancement of Science (AAAS). It includes links to articles on their official website, a physical address for customer service, and options to unsubscribe, which are typical features of legitimate newsletters. There are no requests for personal information or suspicious links that are common in phishing emails.
# Legitimate|Reason: The email appears to be a legitimate bug report related to Perl, a programming language. It includes detailed technical information about a specific issue with Perl's handling of integers and floats, which is typical for bug reports. The email does not request any personal information, financial details, or contain any suspicious links or attachments, which are common indicators of phishing attempts. Additionally, the email includes specific instructions for correspondence and technical details that are consistent with a genuine bug reporting process.
# Legitimate|Reason: The email contains structured information about a mailing list, including instructions for subscribing or unsubscribing, and contact information for the list manager. The email addresses and URLs provided are consistent with the domain of a legitimate academic institution (waikato.ac.nz), which is known for hosting the Weka mailing list. The content is typical of a mailing list digest, listing topics and contributors, and does not request sensitive information or contain suspicious links.
# Legitimate|Reason: The email appears to be a version control update notification from a source code repository, specifically related to the Spambayes project. It includes technical details about changes made to a Python file (storage.py) and is sent from a mailing list associated with the project. There are no signs of phishing, such as requests for personal information or suspicious links.
# Legitimate|Reason: The email content discusses technical details about disk space management and the use of command-line tools, which is typical of a legitimate conversation among IT professionals or system administrators. There are no signs of phishing, such as requests for personal information, suspicious links, or urgent calls to action.
# Phishing|The email contains suspicious and vague content with a call to action to visit an unspecified site, which is a common tactic used in phishing attempts to lure recipients into clicking potentially harmful links.
# Phishing|The email contains suspicious content with references to explicit material and a hyperlink to an unfamiliar and potentially malicious website, which is a common tactic used in phishing attempts to lure recipients into clicking on harmful links.
# Legitimate|Reason: The email body contains a technical discussion about Linux security, malware, and system vulnerabilities. It does not attempt to deceive the recipient into providing sensitive information or clicking on malicious links. The conversation is focused on educating about security practices rather than exploiting the recipient.
# Phishing|The email contains a suspicious link and uses sensational language to entice the recipient to click on it, which is a common tactic used in phishing attempts.
# Phishing|The email offers fake diplomas and degrees without any legitimate academic process, which is a common tactic in phishing scams. The use of misspellings, such as "Bacheelor" and "Doctoraate," and the promise of confidentiality and no requirements are red flags. Additionally, the request for personal information and the emphasis on urgency by providing a phone number to call are typical phishing strategies to exploit individuals.
# Legitimate|The email appears to be a legitimate newsletter from CNN, as it contains a structured format typical of news updates, includes links to CNN's official website, and provides options for managing subscription settings. The presence of CNN's official contact information and privacy guidelines further supports its legitimacy.
# Phishing|The email contains suspicious elements such as a vague offer of medication products, a lack of specific details about the company or products, and a random string of nonsensical words at the end, which is a common tactic used in phishing emails to bypass spam filters.
# Phishing|The email contains a suspicious link and uses vague, enticing language to lure the recipient into clicking it. The content is unrelated and nonsensical, which is typical of phishing attempts designed to bypass spam filters.
# Legitimate|Reason: The email content is a technical discussion about Perl programming, specifically about pattern matching and block scoping. It includes code snippets and a detailed analysis of expected versus actual behavior in Perl code execution. There are no signs of phishing, such as requests for personal information, suspicious links, or urgent calls to action. The language and context are consistent with a legitimate exchange between programmers discussing a technical issue.
# Legitimate|The email does not contain any suspicious elements typically associated with phishing, such as urgent requests for personal information, suspicious links, or attachments. It appears to be a genuine inquiry from a bookstore about a specific book, providing detailed contact information and a mailing list subscription link.
# Legitimate|The email contains content that appears to be a genuine newsletter from CNN, including links to CNN's official website, a professional layout, and a clear unsubscribe option. The email also includes CNN's contact information and privacy guidelines, which are typical of legitimate newsletters. There are no requests for personal information or suspicious links that are common indicators of phishing attempts.
# Phishing|The email contains a suspicious link and uses inappropriate content to entice the recipient, which is a common tactic in phishing attempts.
# Phishing|The email contains a generic and vague message with a call to action ("Click here!") that is typical of phishing attempts. It lacks specific details about the sender, the product, or any legitimate contact information, which are common indicators of phishing emails.
# Legitimate|Reason: The email appears to be a bug tracking notification from the Apache SpamAssassin project. It includes a link to an official Apache website and discusses technical details about bug fixes and voting, which are typical in software development and bug tracking communications. There are no signs of phishing, such as requests for personal information or suspicious links.
# Phishing|Reason: The email contains a suspicious link to an unknown website (http://milddear.com/) and uses vague, enticing language to prompt the recipient to take immediate action. This is a common tactic in phishing attempts to lure individuals into clicking on potentially harmful links. Additionally, the email content is disjointed and lacks context, which is typical of phishing emails that are often poorly constructed.
# Phishing|The email uses persuasive language to encourage the recipient to purchase a product, which is a common tactic in phishing attempts. Additionally, the lack of specific details about the company or product, and the absence of contact information or a professional signature, raises suspicion about its legitimacy.
# Legitimate|The email contains content that appears to be a genuine newsletter from CNN, including links to CNN's official website, a structured format typical of legitimate newsletters, and appropriate contact information. The email also includes privacy guidelines and unsubscribe options, which are common in legitimate communications. There are no suspicious requests for personal information or indications of malicious intent.
# Phishing|The email body consists of random, nonsensical words and phrases that do not form a coherent message. This is a common characteristic of phishing emails designed to bypass spam filters and confuse recipients.
# Legitimate|Reason: The email appears to be a technical discussion about configuring CRM114, a spam filtering software, and troubleshooting issues with its setup. The sender is seeking help with a specific technical problem and provides detailed information about their setup and commands used. The email includes a signature with a legitimate promotional link to GMX TopMail and a footer related to SourceForge, which is a well-known platform for open-source projects. There are no requests for sensitive information or indications of malicious intent, which are typical characteristics of phishing emails.
# Legitimate|Reason: The email appears to be a legitimate news alert from the Winnipeg Free Press, providing breaking news content. It includes a copyright notice, contact information, and an unsubscribe option, which are typical features of legitimate subscription-based news emails. There are no requests for personal information or suspicious links, which are common indicators of phishing attempts.
# Legitimate|Reason: The email body consists of a discussion among users about operating systems, security concerns, and the differences between Linux and Windows. There is no indication of an attempt to deceive the recipient into providing sensitive information, clicking on malicious links, or downloading harmful attachments. The conversation appears to be a genuine exchange of opinions and experiences regarding computer security.
# Phishing|Reason: The email contains a suspicious link and uses inappropriate language, which is a common tactic in phishing attempts to lure recipients into clicking on potentially harmful links. The content is also irrelevant and unprofessional, indicating it is not from a legitimate source.
# Legitimate|Reason: The email appears to be a legitimate newsletter from NBC11, containing a variety of news stories, photo galleries, and videos. It includes a copyright notice from NBC Universal and IBS, Inc., and provides an option to unsubscribe, which is typical for legitimate newsletters. There are no requests for personal information or suspicious links that are common indicators of phishing emails.
# Legitimate|The email appears to be a legitimate newsletter from CNN, providing links to videos and stories on their website. The URLs are consistent with CNN's domain, and the email includes standard footer information such as contact details, privacy guidelines, and subscription management options. There are no signs of phishing tactics such as suspicious links, requests for personal information, or urgent calls to action.
# Legitimate|The email appears to be a legitimate newsletter from CNN, containing links to CNN's official website and providing news stories and videos. The email includes proper branding, contact information, and links to manage subscription settings, which are typical features of a legitimate email from a reputable news organization.
# Legitimate|The email provides detailed information about a legitimate event, the CEAS Live Spam Challenge, including dates, location, and contact information. It includes links to reputable institutions like Microsoft Research, IBM Research, and the University of Waterloo. The email also provides a clear call for participation and contact details, which are consistent with a professional event announcement. Additionally, the email is associated with a mailing list from Stanford University, further supporting its legitimacy.
# ...
# Legitimate|Reason: The email appears to be a legitimate message from a user named Michael discussing technical issues with the CRM114 mail filter setup. The content is technical and specific to the CRM114 software, which is consistent with the subject line and the mailing list context. The email does not contain any suspicious links or requests for personal information, and the links provided are related to SourceForge and GMX, which are known platforms. Additionally, the email is sent to a mailing list, which is a common practice for discussing technical issues.
# Legitimate|Reason: The email appears to be a legitimate news alert from the Winnipeg Free Press. The sender's email address matches the domain of the Winnipeg Free Press, and the content is consistent with a news update. Additionally, the email includes a copyright notice and an unsubscribe option, which are typical features of legitimate email alerts from news organizations. There are no signs of phishing attempts, such as requests for personal information or suspicious links.
# Legitimate|Reason: The email appears to be a legitimate discussion among users of the OpenSuse mailing list. The content is technical and focuses on operating system security, specifically discussing the differences between Linux and Windows security models. There are no requests for personal information, no suspicious links, and the email addresses and subject matter align with a typical technical discussion, indicating it is not a phishing attempt.
# Phishing|The email is classified as phishing because it contains a suspicious link and a subject related to erectile dysfunction, which is a common tactic used in spam and phishing emails to lure recipients into clicking on potentially harmful links. Additionally, the email lacks personalization and context, which are typical characteristics of phishing attempts.
# Legitimate|Reason: The email appears to be a legitimate newsletter from NBC11.com, a local NBC affiliate. The sender's email address is from a domain associated with NBC, and the content includes typical newsletter features such as news stories, photo galleries, and video links. Additionally, it includes standard elements like a privacy policy, terms of use, and an unsubscribe option, which are common in legitimate newsletters. There are no indications of phishing attempts, such as requests for personal information or suspicious links.
# Legitimate|The email appears to be a legitimate newsletter from CNN.com. The links provided in the email body direct to CNN's official website, and the email includes typical elements of a legitimate newsletter, such as a privacy policy link, feedback options, and an unsubscribe link. Additionally, the content and formatting are consistent with a professional newsletter, and there are no signs of phishing tactics such as suspicious links or requests for personal information.
# Legitimate|The email appears to be a legitimate newsletter from CNN.com. The links provided in the email body direct to CNN's official website, and the content is consistent with a typical news update. Additionally, the email includes standard footer information about the sender, privacy guidelines, and options to manage subscription settings, which are common in legitimate newsletters. There are no signs of phishing attempts such as suspicious links, requests for personal information, or unusual sender addresses.
# Legitimate|The email appears to be a legitimate announcement for a past event related to the Conference on Email and Anti-Spam (CEAS) held in 2007. It includes specific details about the event, such as dates, location, and participation information. The sender's email address is associated with a known academic institution (University of Waterloo), and the email provides contact information and links that seem consistent with the context of the event. Additionally, there are no requests for personal information or suspicious links that are typical indicators of phishing emails.
# Legitimate|Reason: The email appears to be a technical discussion about a Linux command-line issue, specifically related to disk usage and mount points. The sender and receiver are discussing a legitimate topic related to the OpenSUSE operating system, and there are no indications of phishing tactics such as requests for personal information, suspicious links, or attachments. The email content is consistent with a typical exchange on a technical mailing list.
# Legitimate|Reason: The email appears to be a genuine conversation between individuals discussing openSUSE, a Linux distribution. The content is consistent with a technical discussion, referencing specific versions of the software and personal experiences related to its use. There are no indications of phishing tactics such as requests for personal information, suspicious links, or urgent calls to action. The sender and receiver addresses, while not corporate, are plausible for a community mailing list exchange.
# Legitimate|Reason: The email appears to be a bug report notification from the Apache SpamAssassin project. The sender and receiver addresses are consistent with the domain used by Apache projects. The content of the email discusses technical details related to a bug report, including a link to the Apache issue tracker, which is a common practice in open-source project communications. There are no signs of phishing attempts, such as requests for personal information or suspicious links.
# Legitimate|The email appears to be a legitimate job posting from a reputable source, Perl Jobs, with a consistent sender and receiver domain (perl.org). The content is detailed and specific to a job opportunity, including job responsibilities, required skills, and contact information. The URLs provided are related to Perl job listings and do not exhibit typical phishing characteristics such as suspicious links or requests for personal information.
# Legitimate|The email appears to be a legitimate job posting from the Perl Jobs mailing list. It includes specific job details, a credible company name (BBC), and URLs that seem to direct to legitimate job-related websites. The email also provides subscription management options typical of legitimate mailing lists. The content and structure align with typical job postings rather than phishing attempts.
# Legitimate|The email appears to be a legitimate newsletter from the Organic Consumers Association, providing information on health, justice, and sustainability topics. The sender's address matches the organization's domain, and the content is consistent with a typical newsletter format, including articles, tips, and calls to action. Additionally, there are no requests for personal information or suspicious links that are common in phishing emails.
# Legitimate|The email appears to be a legitimate job posting from the Perl Jobs mailing list. It includes specific details about the job position, company name, location, and required skills. The sender and receiver addresses are consistent with the Perl Jobs domain, and the URLs provided are related to Perl Jobs and Epsilon, which is a known company. There are no suspicious links or requests for personal information, which are common indicators of phishing emails.
# Phishing|The email is classified as phishing due to several indicators: the sender's email address does not match the supposed sender's name, the subject line contains a suspicious and random string of characters, the body of the email includes sensationalist language to entice the recipient to click on a link, and there is a lack of personalization or context. Additionally, the email's formatting and content are typical of phishing attempts designed to lure recipients into visiting potentially malicious websites.
# Legitimate|The email appears to be a legitimate job posting from a known source, Perl Jobs, which is associated with the Perl community. The email provides specific details about the job, including the company name, location, and job requirements. It also includes URLs that are consistent with the Perl Jobs site and the company's official website, dbds.com. The email does not request any sensitive personal information or direct the recipient to suspicious links, which are common indicators of phishing attempts.
# Legitimate|Reason: The email appears to be a legitimate request for assistance related to the use of the SpamBayes software. The sender, Wilhelm Klenner, is discussing issues with false positives in the software and is seeking advice from a relevant mailing list. The language used is consistent with a technical support query, and there are no indications of phishing tactics such as urgent requests for personal information, suspicious links, or attachments. Additionally, the email is directed to a specific mailing list related to SpamBayes development, which aligns with the content of the message.
# Phishing|The email is classified as phishing because it promotes gambling with promises of easy money, which is a common tactic used in phishing scams. The sender's email address appears suspicious and unrelated to the content, and the email contains a hyperlink to an external site, which could potentially lead to a malicious website. Additionally, the email uses generic language and lacks personalization, which are typical characteristics of phishing attempts.
# Phishing|The email is classified as phishing due to several red flags: the sender's email address appears suspicious and unrelated to the content, the subject line is designed to attract attention with a money-back guarantee, and the body promotes a product with vague claims and no credible information or contact details. Additionally, the email is from 2008, which is outdated and unusual for a legitimate offer.
# Legitimate|The email is a legitimate query sent to a mailing list related to R programming. The sender is asking for advice on statistical analysis methods for a dataset, which is a common type of inquiry on such forums. The email includes specific details about the statistical problem and references to R functions and packages, indicating a genuine request for help rather than an attempt to deceive or extract sensitive information. Additionally, the email includes a footer with information about the mailing list, which is typical for legitimate mailing list communications.
# Phishing|The email contains several indicators of phishing: a suspicious and unrelated subject line, a generic and unsolicited offer, and a hyperlink to an unknown and potentially malicious website. Additionally, the body text is disjointed and includes irrelevant content, which is a common tactic in phishing emails to bypass spam filters.
# Legitimate|The email appears to be a legitimate job posting from a known source, Perl Jobs, with specific details about the position, company, and contact information. The URLs provided are consistent with the Perl Jobs website, and there is no request for sensitive personal information or any suspicious links.
# Phishing|The email is classified as phishing due to several red flags: the sender's name does not match the email address, which is a common tactic in phishing to disguise the true sender. The subject line is vague and unrelated to the body content, which is often used to entice the recipient to open the email. Additionally, the body contains a generic and poorly constructed message with a call to action to "check out" something without providing specific or credible information. The lack of personalization and context further suggests it is not a legitimate communication.
# Legitimate|The email appears to be a legitimate newsletter from CNN.com. The links provided in the email body direct to CNN's official website, and the content is consistent with a typical news update. The email includes standard footer information, such as privacy guidelines and unsubscribe options, which are common in legitimate newsletters. Additionally, the email does not request any personal information or contain suspicious attachments.
# Phishing|The email exhibits several characteristics of a phishing attempt: the sender's email address appears suspicious and unrelated to the content, the subject line is vague and enticing, and the body contains nonsensical text, which is often used to bypass spam filters. Additionally, there is no personal greeting or specific information, which is typical of phishing emails attempting to cast a wide net.
# Phishing|The email is suspicious due to several factors: the sender's email address (rezilatn1993@freemail.selfip.org) does not match CNN's official domain, which would typically be something like @cnn.com. Additionally, the email is sent to an unusual domain (gvc.ceas-challenge.cc), which is not typical for CNN's distribution. The email also contains numerous links, which could potentially lead to phishing sites, despite appearing to be legitimate CNN URLs. These inconsistencies suggest that the email is likely a phishing attempt.
# Legitimate|The email appears to be a legitimate newsletter from CNN.com. The links provided in the email body direct to CNN's official website, and the content is consistent with a typical news update. Additionally, the email includes standard footer information about the sender, privacy guidelines, and options to manage subscription settings, which are typical features of legitimate newsletters.
# Phishing|The email promotes the sale of prescription drugs without a prescription, which is illegal and a common tactic used in phishing scams. The sender's email address appears suspicious and unprofessional, and the message contains a call to action to click on a link, which is a typical phishing strategy to lure recipients into visiting potentially malicious websites. Additionally, the promise of no doctor's visits and unlimited quantities raises red flags about the legitimacy of the offer.
# Phishing|The email is classified as phishing because it promotes counterfeit luxury items, which is a common tactic used in phishing schemes. The sender's email address appears suspicious and unrelated to the content, and the email contains a link to an untrustworthy website, which could potentially lead to malicious sites or scams. Additionally, the email's subject and body are typical of spam or phishing attempts that aim to lure recipients into purchasing fake products.
# Legitimate|Reason: The email appears to be a summary of discussions from the Python-Dev mailing list, which is a legitimate forum for Python developers to discuss development-related topics. The content includes detailed summaries of technical discussions, bug reports, and proposals, which are typical of a developer mailing list. The sender's email address, while not from an official domain, does not necessarily indicate phishing in this context, as personal email addresses are sometimes used in open-source communities. Additionally, there are no requests for personal information, financial details, or suspicious links that are common indicators of phishing attempts.
# Phishing|The email is classified as phishing due to several red flags: the sender's email address appears suspicious and not related to any known organization, the subject line is vague and unrelated to the recipient, the body contains a generic and unclear message with a potentially malicious link, and the date is significantly outdated, which is unusual for legitimate communications.
# ✅ Processed: header_body_sample_75_without_label.csv → Saved to /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/zeroshot/header_body_sample_75_without_label_predicted.xlsx

# %% [markdown]
# # Fewshot analysis

# %%
process_sample_75_few_shot("header_sample_75_without_label.csv", "header")
process_sample_75_few_shot("body_sample_75_without_label.csv", "body")
process_sample_75_few_shot("header_body_sample_75_without_label.csv", "combined")
# Out:
# Phishing | The subject line is unusual and potentially manipulative, and the sender's email address is unfamiliar.
# Phishing | The sender's email address is suspicious and the subject line is unusual and potentially misleading.
# Phishing | The sender's email address is suspicious and does not match the purported source.
# Phishing | The sender's email address does not match the name, and the subject line is technical and unrelated, which is often a tactic used in phishing attempts.
# Phishing | The sender's email address is suspicious, and the subject line is misleading and unrelated to the sender's domain.
# Phishing | The sender's email address does not match the name, and the email appears suspicious.
# Phishing | The email promotes replica watches and uses a misleading sender name, indicating potential spam or phishing.
# Phishing | The sender's email address does not match the expected domain for CNN and appears suspicious.
# Legitimate | The email is from a known open-source project domain discussing a technical issue.
# Phishing | The sender's email address does not match the purported source, and the format is suspicious.
# Phishing | The sender's email address does not match the name, and the subject is related to financial services, which is a common phishing tactic.
# Phishing | The sender's email address is suspicious and the subject line is vague and potentially misleading.
# Phishing | The sender's email address does not match the expected domain for CNN and appears suspicious.
# Phishing | The sender's email address does not match the expected domain for CNN and appears suspicious.
# Legitimate | The email appears to be from an individual with a specific subject line that doesn't suggest urgency or request sensitive information.
# Phishing | The sender's email address does not match the name, which is suspicious.
# Phishing | The sender's email address is unrelated to the subject and appears suspicious.
# Phishing | The sender's email address is unrelated to the subject and appears suspicious.
# Legitimate | The email appears to be part of a discussion on a mailing list, with a specific technical question and a sender that matches the context.
# Legitimate | The email appears to be part of a legitimate discussion thread about openSUSE, and the sender's name is provided.
# Legitimate | The email appears to be a regular alert from a known scientific organization.
# Legitimate | The email appears to be related to a technical discussion or bug report from a known mailing list or community.
# Legitimate | The email appears to be from a mailing list with a specific format and subject, which is typical for legitimate listserv communications.
# Legitimate | The email appears to be a version control update notification from a known open-source project, SourceForge.
# Legitimate | The email appears to be part of a technical discussion on a mailing list, and the subject matter is consistent with such exchanges.
# Phishing | The subject is inappropriate and the sender's email is suspicious.
# Legitimate | The email appears to be from an individual with a specific name and email address, and the subject suggests a personal transaction.
# Legitimate | The email appears to be part of a discussion on a mailing list related to OpenSuse, and there are no immediate signs of phishing.
# Phishing | The sender's email address is unusual and the subject is unrelated to the sender's domain, indicating potential phishing.
# Phishing | The sender's email address does not match the subject content, and the subject line contains a suspicious offer.
# Phishing | The sender's email address does not match the official domain of CNN, which is suspicious.
# Phishing | The sender's email address does not match the subject and seems unrelated, which is suspicious.
# Legitimate | The email appears to be from an individual with a personal email address and does not contain any immediate red flags indicating phishing.
# Legitimate | The email appears to be a response to a technical discussion, and the sender's address is consistent with a known organization.
# Legitimate | The email appears to be from a known sender discussing a specific topic, without any urgent call to action.
# Phishing | The sender's email address does not match the claimed source, and the format is suspicious.
# Phishing | The email lacks a proper sender address and the subject is suspicious.
# Phishing | The subject line is suspicious and potentially misleading.
# Legitimate | The email is from a known domain related to Apache, discussing a technical issue, which is typical for bug tracking and review communications.
# Phishing | The subject line is vague and sensational, which is a common tactic in phishing emails.
# Phishing | The sender's email address does not match the subject matter, and the email is unsolicited.
# Phishing | The sender's email address does not match the expected domain for CNN, which is suspicious.
# Phishing | The sender's email address does not match the name, and the subject line is nonsensical, which are common signs of phishing.
# Legitimate | The email appears to be from a mailing list announcement related to CRM114, a known open-source software project. The sender's email format and subject line are consistent with a technical discussion or announcement.
# Legitimate | It’s a breaking news alert from a recognized news source.
# Phishing | The sender's email address is suspicious and does not match the subject matter.
# Phishing | The email lacks a proper sender address and the subject is indicative of spam or phishing content.
# Legitimate | The email is from a known news source and does not urge immediate action.
# Phishing | The sender's email address does not match the expected domain for CNN, which is suspicious.
# Legitimate | The email appears to be a regular newsletter from a known source, and there are no immediate signs of phishing.
# Legitimate | The email appears to be from a known individual associated with a reputable institution, and the subject suggests a legitimate event or challenge.
# Legitimate | The email appears to be part of a discussion on a technical mailing list, which is typical for open-source communities.
# Phishing | The sender's email address is suspicious and does not match the subject matter.
# Legitimate | The email is from a known domain related to Apache, discussing a technical issue, which is typical for bug tracking communications.
# Legitimate | The email is from a known mailing list for job opportunities related to Perl, and the sender's address matches the expected domain.
# Legitimate | The email appears to be from a legitimate source related to job postings, and there are no immediate red flags indicating phishing.
# Legitimate | It appears to be a newsletter from a recognized organization with a consistent sender address.
# Legitimate | The email appears to be from a legitimate job posting list related to Perl, with specific details about the job and location.
# Phishing | The sender's email address is unusual and the subject line is suspiciously vague and contains a random string of characters.
# Legitimate | The email is from a known mailing list related to job opportunities in the Perl community.
# Legitimate | The email appears to be part of a mailing list discussion from a known sender.
# Phishing | The sender's name and email address do not match, the subject is overly promotional, and the date is outdated, which are common signs of phishing.
# Phishing | The sender's email address does not match the name, and the subject line is typical of scam tactics.
# Legitimate | The email appears to be a personal or professional inquiry without any suspicious elements.
# Phishing | The subject is suspicious and the sender's email address is not recognizable as a legitimate source.
# Legitimate | The email is from a known mailing list related to Perl jobs, and the sender's address aligns with the context.
# Phishing | The sender's name and email do not match, which is suspicious.
# Phishing | The sender's email address is suspicious and does not match the expected domain for CNN.
# Phishing | The sender's email address does not match the subject, and the offer of "happiness" is vague and suspicious.
# Phishing | The sender's email address is suspicious and does not match the claimed source.
# Phishing | The sender's email address does not match the expected domain for CNN, and the format is suspicious.
# Phishing | The email is promoting prescription drugs without a prescription, which is a common tactic used in phishing and spam emails.
# Phishing | The email subject suggests a spam or scam attempt, and the sender's email address does not match the content.
# Legitimate | The email appears to be a part of a mailing list discussion, and the sender's name matches the context of the subject.
# Phishing | The sender's email address is suspicious and does not match the name, and the subject is vague and potentially misleading.
# ✅ Few-shot processed and saved → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/fewshot/header_sample_75_without_label_fewshot_predicted.xlsx
# Phishing | Contains suspicious link and inappropriate content.
# Phishing | Suspicious content and link included.
# Legitimate | Contains official CNN content, recognizable URLs, and subscription management links.
# Legitimate | The email contains a technical discussion about domain names and TLDs, with no signs of phishing attempts.
# Phishing | Suspicious link and lack of context or recognizable branding.
# Phishing | The message is nonsensical and may contain obfuscated text to bypass filters.
# Phishing | Offers counterfeit products and lacks professionalism.
# Legitimate | The email contains structured content with valid CNN links and subscription management options.
# Legitimate | This appears to be a bug tracking notification from a recognized open-source project, with no urgent tone or suspicious links.
# Legitimate | The email contains structured content with valid links to CNN's website and includes unsubscribe and privacy information, typical of a legitimate newsletter.
# Phishing | Promises unrealistic debt elimination and includes suspicious links.
# Phishing | Suspicious link and offer for software at potentially unauthorized or discounted rates.
# Legitimate | The email contains detailed news content and links to CNN's official website, with proper branding and unsubscribe options.
# Legitimate | Contains official CNN content and links to CNN's website, consistent with a newsletter format.
# Phishing | Contains suspicious claims and a non-reputable link.
# Legitimate | The email contains a normal business communication regarding a certificate application, with no suspicious links or urgent requests.
# Legitimate | The email contains multiple legitimate CNN links, a structured format, and clear unsubscribe and preference management options.
# Legitimate | Contains detailed content from a reputable source with valid links and subscription management options.
# Legitimate | Technical discussion on a mailing list with no signs of phishing.
# Legitimate | The email contains a series of technical discussions and exchanges related to the Weka machine learning workbench, including troubleshooting and technical advice. There are no signs of phishing, such as suspicious links or requests for sensitive information.
# Legitimate | Informative newsletter from a reputable science publication with no suspicious links or urgent requests.
# Legitimate | Detailed technical bug report related to Perl, no signs of phishing.
# Legitimate | This email appears to be a typical mailing list digest with no suspicious links or urgent requests.
# Legitimate | This appears to be a source code update notification from a version control system, typical for development projects.
# Legitimate | Technical discussion about disk space management with no suspicious elements.
# Phishing | Suspicious content and call to action with no context.
# Phishing | Suspicious content and link included.
# Legitimate | This is a technical discussion about Linux security, not a phishing attempt.
# Phishing | Suspicious content and link included.
# Phishing | Offers unrealistic educational credentials with no requirements, uses poor spelling/grammar, and requests personal information.
# Legitimate | Contains detailed news content and links from a reputable source (CNN), with proper unsubscribe and privacy information.
# Phishing | The email contains nonsensical text and a suspicious link, which are common indicators of phishing attempts.
# Phishing | Suspicious link and unsolicited content about personal life improvements.
# Legitimate | Technical discussion about Perl programming behavior.
# Legitimate | Informational request from a book seller with contact details and no suspicious elements.
# Legitimate | The email contains official CNN links and branding, consistent with a newsletter subscription.
# Phishing | Suspicious content and link included.
# Phishing | Unusual formatting and unsolicited promotional link.
# Legitimate | This appears to be a bug tracking notification from a legitimate source, with no urgent tone or suspicious links.
# Phishing | Suspicious link and promotional language aimed at enticing action.
# Phishing | Unusual formatting and promotional content with potential for misleading claims.
# Legitimate | The email contains structured content with valid CNN links and subscription management options.
# Spam | The email body is nonsensical and lacks a coherent message, indicating it is likely spam.
# Legitimate | Technical discussion on email filtering with no suspicious elements.
# Legitimate | Appears to be a newsletter or news alert from a reputable source with unsubscribe option.
# Legitimate | This is a discussion about operating system security, not a phishing attempt.
# Phishing | Suspicious content and link included.
# Legitimate | This appears to be a newsletter from a news website with various articles and updates.
# Legitimate | Contains detailed information, valid links to CNN, and unsubscribe options consistent with a legitimate newsletter.
# Legitimate | Contains official CNN links and subscription management options.
# Legitimate | Informative email about a conference and competition with credible details and contact information.
# Legitimate | Technical discussion about filesystem management with no signs of phishing.
# Legitimate | Personal email conversation with no signs of phishing.
# Legitimate | This appears to be a bug tracking notification from a legitimate open-source project, with no suspicious links or urgent requests.
# Legitimate | Detailed job posting with specific information and credible URLs.
# Legitimate | Detailed job posting with specific information and reputable links.
# Legitimate | Informative newsletter with detailed content and credible sources.
# Legitimate | Detailed job posting with specific requirements and reputable URLs.
# Phishing | Suspicious and vague content with a call to action to visit a site.
# Legitimate | Detailed job posting with specific information and credible URLs.
# Legitimate | The email discusses technical issues with a spam filter and requests assistance, with no signs of phishing.
# Phishing | Enticing language and suspicious link promoting gambling.
# Potentially Unwanted | The email promotes a product with health claims and guarantees, which can be a red flag for spam or misleading marketing.
# Legitimate | This is a technical question posted to a mailing list about statistical analysis in R, with no signs of phishing.
# Phishing | Suspicious link and inappropriate content included.
# Legitimate | Detailed job listing with specific contact information and no suspicious links.
# Phishing | Poor grammar and lack of specific details, along with a suspicious call to action.
# Legitimate | Contains official CNN links and standard newsletter format.
# Phishing | The email contains nonsensical text and lacks coherence, which is a common tactic used in phishing to bypass spam filters. Additionally, it includes a vague call to action ("Here!") without a clear or legitimate context.
# Legitimate | The email contains detailed content from a reputable source (CNN) with valid links and subscription management options.
# Legitimate | The email contains detailed news content, valid CNN links, and proper subscription management information.
# Phishing | Promotes illegal activity, offers prescription drugs without a prescription, and includes a suspicious link.
# Phishing | Promotes counterfeit products and includes a suspicious link.
# Legitimate | This email appears to be a summary of discussions and updates from a Python development mailing list, with no signs of phishing attempts.
# Phishing | Suspicious link and unusual formatting with no clear context.
# ✅ Few-shot processed and saved → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/fewshot/body_sample_75_without_label_fewshot_predicted.xlsx
# Phishing | Suspicious and unsolicited content, potentially harmful link, and irrelevant subject matter.
# Phishing | Suspicious sender, unrelated subject, and potentially malicious link.
# Legitimate | The email appears to be a legitimate newsletter from CNN with proper formatting, known sender, and no suspicious links.
# Legitimate | The email is a technical discussion related to software development, with no suspicious links or urgent calls to action. The sender's email address, although not a well-known domain, is consistent with a mailing list or internal communication within a development community.
# Phishing | Suspicious sender, vague subject, and untrustworthy link.
# Phishing | The sender's email address is suspicious, and the body contains nonsensical text, which is a common tactic in phishing attempts.
# Phishing | Suspicious sender, unrelated content, and promotion of counterfeit products.
# Legitimate | The email appears to be a genuine newsletter from CNN with valid links and proper branding.
# Legitimate | The email is related to a bug report from a known open-source project, Apache, and contains no suspicious elements.
# Legitimate | The email contains detailed content consistent with a newsletter, includes legitimate CNN links, and provides clear instructions for managing preferences and unsubscribing.
# Phishing | Unsolicited offer with unrealistic claims and suspicious links.
# Phishing | Suspicious sender, unrelated content, and a potentially malicious link.
# Phishing | The sender's email address is suspicious and does not match CNN's official domain.
# Legitimate | The email contains detailed content, legitimate links to CNN, and clear instructions for managing preferences, consistent with a newsletter from a known source.
# Phishing | Suspicious content, unsolicited offer, and potentially malicious link.
# Legitimate | The email appears to be part of an ongoing conversation regarding a specific application process. The sender's email address matches the domain of the organization mentioned, and there are no suspicious links or urgent calls to action.
# Legitimate | The email contains detailed content consistent with a newsletter, links to a reputable source (CNN), and provides options to manage preferences and unsubscribe.
# Legitimate | The email contains links to CNN's official website, follows a structured format, and includes options to manage preferences and unsubscribe, indicating it is a legitimate newsletter from CNN.
# Legitimate | The email is part of a technical discussion on a mailing list, with no suspicious elements or requests for sensitive information.
# Legitimate | The email appears to be a legitimate discussion from a mailing list related to Weka, a machine learning software. It includes technical discussions, questions, and responses typical of a user group or forum. There are no suspicious links or urgent calls to action, and the email addresses and content align with the context of a technical mailing list.
# Legitimate | Contains detailed content, links to known scientific publication, and clear unsubscribe options.
# Legitimate | The email appears to be a legitimate bug report related to Perl, with detailed technical information and no suspicious elements.
# Legitimate | This email is a typical mailing list digest with no suspicious elements, providing information on how to manage subscriptions.
# Legitimate | The email is a technical update from a known open-source project, with no suspicious links or urgent calls to action.
# Legitimate | Technical discussion, no suspicious elements, from a mailing list.
# Phishing | Suspicious subject line, inappropriate content, and unknown sender.
# Phishing | Suspicious content, unrelated subject, and a potentially malicious link.
# Legitimate | This is a technical discussion about Linux security, not a phishing attempt. The email contains no suspicious links or requests for sensitive information.
# Phishing | Suspicious sender, unrelated subject, and a potentially malicious link.
# Phishing | Suspicious sender, offers unrealistic services, and requests personal information.
# Legitimate | The email appears to be a genuine newsletter from CNN, with proper branding, legitimate links, and clear instructions for managing subscription settings.
# Phishing | Suspicious sender, unrelated subject, and nonsensical body content.
# Phishing | Suspicious subject and content, includes a potentially malicious link.
# Legitimate | Technical discussion with detailed code and analysis, no suspicious elements.
# Legitimate | The email is from a known sender, contains no suspicious links, and is part of a mailing list discussion.
# Legitimate | The email appears to be a genuine newsletter from CNN with valid links and proper branding.
# Phishing | Suspicious content, lack of sender's email address, and potentially malicious link.
# Phishing | Suspicious sender, inappropriate subject, and call-to-action with a vague offer.
# Legitimate | The email is a bug report from a known open-source project mailing list, with no suspicious links or urgent requests.
# Phishing | Suspicious subject line, unsolicited offer, and unknown link.
# Phishing | Unfamiliar sender, promotional content, and potential scam product.
# Legitimate | The email contains detailed content from a known source (CNN), includes legitimate links, and provides clear unsubscribe options.
# Phishing | The email contains nonsensical and random text, which is a common tactic used in phishing to bypass spam filters. The sender's email address and content do not match any legitimate communication.
# Legitimate | The email is a technical discussion about CRM114 filters, contains no suspicious links or urgent requests, and is from a mailing list.
# Legitimate | Recognizable sender, consistent content with news alerts, and unsubscribe option provided.
# Legitimate | This email appears to be part of a legitimate discussion thread on a mailing list about operating systems, with no suspicious links or urgent calls to action.
# Phishing | Suspicious content, unsolicited offer, and potentially malicious link.
# Legitimate | The email appears to be a newsletter from a known source, NBC11.com, with no urgent call-to-action or suspicious links.
# Legitimate | The email contains detailed information, links to a reputable source (CNN), and includes options to manage preferences or unsubscribe.
# Legitimate | The email contains detailed information, legitimate links to CNN's website, and clear instructions for managing email preferences.
# Legitimate | The email provides detailed information about a past event, includes contact information, and links to reputable sources. The sender's email domain matches the context of the message.
# Legitimate | The email is part of a technical discussion on a mailing list, with no suspicious elements or requests for sensitive information.
# Legitimate | The email is part of a discussion thread from a mailing list, with no suspicious elements or urgent requests.
# Legitimate | The email is a bug report from a known open-source project, Apache SpamAssassin, with no suspicious elements.
# Legitimate | Detailed job listing from a known source with no suspicious elements.
# Legitimate | Detailed job listing, no suspicious elements, from a known community mailing list.
# Legitimate | The email is from a known organization, contains detailed information, and does not have any suspicious links or urgent calls to action.
# Legitimate | Detailed job listing from a known domain with no suspicious elements.
# Phishing | Suspicious sender, vague subject, and an enticing call-to-action with no clear context.
# Legitimate | The email is from a known mailing list, provides detailed job information, and includes legitimate URLs for more information.
# Legitimate | The email is a discussion about a technical issue with a spam filter, contains no suspicious links, and is from a known individual.
# Phishing | Suspicious sender, promotional content, and potentially malicious link.
# Phishing | Unfamiliar sender, unsolicited offer, and potential health scam.
# Legitimate | The email is a technical discussion on statistical analysis, from a personal email address, with no suspicious links or urgent requests.
# Phishing | Suspicious and inappropriate content, unusual sender, and potentially malicious link.
# Legitimate | Detailed job listing, consistent with known job posting practices, no suspicious links or urgent actions.
# Phishing | Suspicious sender name and email mismatch, vague subject, and unclear purpose.
# Legitimate | The email appears to be a genuine newsletter from CNN, containing links to CNN's official website and providing clear instructions for managing subscription preferences.
# Phishing | Unrelated and nonsensical content, suspicious sender, and vague offer.
# Legitimate | The email appears to be a genuine newsletter from CNN with valid links and proper branding.
# Legitimate | The email appears to be a newsletter from CNN with valid links and proper branding.
# Phishing | Suspicious sender, unsolicited offer, and potentially harmful link.
# Phishing | Suspicious sender, unrelated subject, and promotion of counterfeit goods with a suspicious link.
# Legitimate | The email is a detailed summary of Python-Dev mailing list discussions, with no suspicious elements or calls to action.
# Phishing | Suspicious sender, unrelated subject, and random link.
# ✅ Few-shot processed and saved → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/fewshot/header_body_sample_75_without_label_fewshot_predicted.xlsx

# %% [markdown]
# # Chain of thought analysis

# %%
process_chain_of_thought("header_sample_75_without_label.csv", "header")
process_chain_of_thought("body_sample_75_without_label.csv", "body")
process_chain_of_thought("header_body_sample_75_without_label.csv", "combined")
# Out:
# Phishing | The subject line "Never agree to be a loser" is suspicious and potentially manipulative, which is a common tactic in phishing emails to provoke an emotional response. Additionally, the sender's email address does not match the receiver's domain, which can be another indicator of phishing.
# Phishing | The email header contains several red flags: the sender's email address appears suspicious and unprofessional, the subject line is unusual and potentially misleading, and the email's context does not align with typical legitimate communication.
# Phishing | The sender's email address does not match the expected domain for CNN, which should be something like @cnn.com. The unusual domain and the mismatch between the sender's name and email address suggest phishing.
# Phishing | The sender's email address appears suspicious and does not match the expected domain for someone likely involved in a legitimate communication with the SpamAssassin development team.
# Phishing | The email header contains several red flags: the sender's email address is from a domain that doesn't match the subject matter, the subject line is suspicious and unrelated to the sender's domain, and the email is unsolicited with a generic subject that often indicates spam or phishing attempts.
# Phishing | The sender's email address appears suspicious and does not match the name "Caroline Aragon." The domain "thaidomainnames.com" is unrelated to the context, which is a common tactic used in phishing attempts.
# Phishing | The email is likely phishing due to the sender's name "Replica Watches," which suggests a potential scam or spam related to counterfeit products. Additionally, the use of a business domain "thebakercompanies.com" for sending such content is suspicious and not typical for legitimate business communications.
# Phishing | The sender's email address appears suspicious and does not match the official domain of CNN, which raises a red flag for phishing.
# Legitimate | The email appears to be related to a bug report or issue tracking within the Apache project, specifically referencing SpamAssassin, which is a legitimate open-source project. The sender and receiver addresses are consistent with Apache's domain, and the subject matter is technical and relevant to the project.
# Phishing | The sender's email address appears suspicious and does not match the expected domain for CNN, which should be something like cnn.com. Additionally, the use of a generic email address from a different domain (musicaedischi.it) is a common tactic used in phishing attempts.
# Phishing | The email header shows a suspicious sender address that does not match the subject matter, which is a common tactic in phishing attempts. Additionally, the use of a generic subject like "debt consolidation" is often used in phishing emails to entice recipients to open the email.
# Phishing | The sender's email address appears suspicious and unrelated to the subject matter, which is a common tactic in phishing attempts. Additionally, the subject line is vague and seems designed to entice the recipient with a too-good-to-be-true offer, another common phishing characteristic.
# Phishing | The sender's email address does not match the expected domain for CNN, which raises suspicion. Additionally, the use of a generic name like "Daily Top 10" and an unusual domain "weijgers.nl" suggests it could be a spoofed email.
# Phishing | The sender's email address (Scooter-obailat@picklesmaternity.com) does not match the expected domain for CNN, which should be something like cnn.com. This discrepancy is a common indicator of phishing attempts.
# Phishing | The email header contains several red flags: the sender's email address appears suspicious and unrelated to the subject, the subject line is vague and unusual, and the date is outdated, which is often a tactic used in phishing to bypass filters.
# Phishing | The sender's email address domain (sailing.ie) does not match the context of the subject (Trial IRC Certificate Application), which could indicate an attempt to deceive the recipient.
# Phishing | The sender's email address (Joep-ntorions@picklesmaternity.com) does not match the expected domain for a legitimate CNN communication, which should be from cnn.com or a related domain. This discrepancy is a common indicator of phishing attempts.
# Phishing | The sender's email address domain "picklesmaternity.com" does not match the expected domain for a legitimate CNN communication, which would typically be from "cnn.com" or a related domain. This discrepancy is a common indicator of phishing attempts.
# Phishing | The sender's email address appears suspicious and does not match a typical corporate or organizational domain, which is a common indicator of phishing attempts.
# Phishing | The email header shows a suspicious sender email address with a random-looking username and a free email service (hotpop.com), which is often used in phishing attempts. Additionally, the subject line suggests a reply to a forwarded message, which is a common tactic to make phishing emails appear as part of an ongoing conversation.
# Phishing | The sender's email address appears suspicious with a random string before the domain, which is a common tactic in phishing. Additionally, the domain "aaas-alerts.org" does not clearly match a known legitimate organization, and the date format seems unusual.
# Legitimate | The email appears to be a legitimate message related to a bug report or discussion within the Perl community, as indicated by the subject line and the use of Perl-related domains (perl.org and develooper.com). The format and context suggest it is part of a technical mailing list or issue tracker.
# Legitimate | The email appears to be a digest from a mailing list associated with the domain "waikato.ac.nz," which is the University of Waikato in New Zealand. The sender and receiver addresses are consistent with a mailing list format, and the subject line indicates a typical digest issue, which is common for legitimate mailing lists.
# Phishing | The sender's email address appears suspicious and unrelated to the subject matter. Additionally, the use of a SourceForge domain and the context of the email suggest it could be an attempt to impersonate a legitimate service or project, which is a common tactic in phishing attempts.
# Phishing | The sender's email address appears suspicious and does not match the expected domain for a legitimate communication regarding an openSUSE issue. Additionally, the use of a free email service like hotpop.com for what seems to be a technical discussion raises red flags.
# Phishing | The subject line is suspicious and inappropriate, which is a common tactic used in phishing emails to entice users to click on malicious links. Additionally, the sender's email address does not match the content of the subject, further indicating it may be a phishing attempt.
# Phishing | The email subject "Your order" is generic and could be used to lure recipients into clicking malicious links or providing personal information. Additionally, the sender's email domain "goline.ca" does not provide enough context to verify its legitimacy, especially without further information about the recipient's interactions with this domain.
# Phishing | The sender's email address appears suspicious and does not match the typical format for a legitimate organization or individual associated with OpenSuse. Additionally, the use of a free email service like hotpop.com for what appears to be an official communication raises red flags.
# Phishing | The email header shows a suspicious sender address from an educational domain, which is unlikely to be associated with a legitimate business offering herbal products. Additionally, the subject line is unrelated to educational content, suggesting a potential phishing attempt.
# Phishing | The email header contains several red flags: the sender's email address does not match the name, the subject line is suspiciously worded with a typo ("Degreees"), and the domain appears unrelated to the subject matter.
# Phishing | The sender's email address (steins@4000down.com) does not match the legitimate domain of CNN, which would typically be something like @cnn.com. This discrepancy is a common indicator of phishing attempts.
# Phishing | The email header is suspicious due to the mismatch between the sender's name and the email address domain, which appears to be from a city government domain but is unrelated to the subject of "Man's stuff store." Additionally, the subject line is vague and could be indicative of a phishing attempt.
# Phishing | The subject line "Change your weakness to power" is vague and could be a tactic to entice the recipient to open the email. Additionally, the email is from 2008, which is unusual unless there is a specific reason for referencing such an old email. The sender's domain "archie.dk" does not provide enough context to verify its legitimacy, and the email could potentially be part of a phishing attempt.
# Legitimate | The email header appears to be a response to a technical query about regex, which is a common topic among developers. The sender's domain "crypt.org" could be associated with cryptography or technical discussions, and there are no immediate red flags such as suspicious links or requests for sensitive information.
# Legitimate | The email header shows a specific sender and receiver that appear to be related to book sales or inquiries, and there are no immediate red flags such as suspicious email addresses or unusual subject lines that are typical of phishing attempts.
# Phishing | The sender's email address appears suspicious and does not match the expected domain for CNN. Additionally, the use of a Japanese domain (co.jp) for a CNN-related email is unusual and raises red flags.
# Phishing | The email header lacks a proper sender's email address, which is a common characteristic of phishing attempts. Additionally, the subject line is suspicious and unrelated to typical professional or personal communication, further indicating a potential phishing attempt.
# Phishing | The subject line is suspicious and inappropriate, which is a common tactic in phishing emails to attract attention or provoke a reaction. Additionally, the sender's email address does not provide clear context or legitimacy, and the email's content is likely unrelated to any legitimate business or personal communication.
# Legitimate | The email header indicates that it is related to a bug review within the Apache project, specifically SpamAssassin. The sender and receiver addresses are consistent with Apache's domain, and the subject matter is technical, aligning with typical open-source project communications.
# Phishing | The subject line "Mega-huge dimension for you!" is vague and suspicious, which is a common tactic in phishing emails to entice recipients to open the email. Additionally, the email address domain "allianz.pt" does not match the typical domain for Allianz, a well-known insurance company, which usually uses "allianz.com" or a country-specific variation that aligns with their official operations. This discrepancy suggests the email may be attempting to impersonate a legitimate organization.
# Phishing | The email header shows signs of phishing, such as a suspicious sender email address that doesn't match the subject matter, and the subject line is often used in spam or phishing attempts. Additionally, the date is quite old, which is unusual for a legitimate email.
# Phishing | The sender's email address does not match the expected domain for CNN, which raises suspicion. Additionally, the email is from 2008, which could indicate it is part of a phishing attempt using outdated or compromised data.
# Phishing | The email header contains several red flags: the sender's email address does not match the name, the subject line is nonsensical and likely generated to bypass spam filters, and the domain "defamer.com" is unrelated to the receiver's domain, suggesting a lack of legitimate business context.
# Legitimate | The email header appears to be from a mailing list on SourceForge, which is a platform commonly used for open-source projects. The subject line indicates a discussion about CRM114, a well-known open-source text classification program. The sender's email domain (gmx.de) is a legitimate German email service provider, and the format of the email aligns with typical mailing list communications.
# Legitimate | The sender's email address appears to be from a legitimate domain associated with the Winnipeg Free Press, and the subject line is consistent with a news alert service. However, further analysis of the email content and any links would be necessary for a definitive conclusion.
# Phishing | The email header shows a suspicious sender address with a random-looking username and a free email service (hotpop.com), which is often used in phishing attempts. Additionally, the email is from 2008, which could indicate an outdated or compromised account being used for phishing.
# Phishing | The subject line is indicative of a common spam or phishing tactic related to health or medication, and the lack of a full email address for the sender is suspicious.
# Legitimate | The sender's email address uses a domain (nbclocal.com) that is consistent with NBC's local news stations, and the subject line does not contain any typical phishing red flags such as urgent calls to action or suspicious links.
# Phishing | The sender's email address does not match the expected domain for CNN, which would typically be something like @cnn.com. Additionally, the use of a seemingly random email address from a different domain (kamis.pl) is suspicious and indicative of phishing attempts.
# Phishing | The sender's email domain "jasonjones.com" does not match the expected domain for CNN, which raises suspicion about the authenticity of the email.
# Legitimate | The email header appears to be from a university domain (uwaterloo.ca), which is consistent with an academic context. The subject refers to a specific event, "CEAS 2007 Live Spam Challenge," which aligns with academic or research activities. There are no immediate red flags such as suspicious links or requests for sensitive information.
# Phishing | The sender's email address appears suspicious and does not match the expected domain for a legitimate communication related to OpenSUSE. Additionally, the use of a generic email service like "hotpop.com" for what seems to be a technical discussion raises red flags.
# Phishing | The email header shows a suspicious sender address with a random-looking username and a free email service (hotpop.com), which is often used in phishing attempts. Additionally, the email is supposedly related to openSUSE, but the sender's address does not match any official openSUSE domain, raising further suspicion.
# Legitimate | The email appears to be related to a bug report or review concerning a technical issue with SpamAssassin, a well-known open-source project under the Apache Software Foundation. The sender's domain matches the Apache organization, and the subject matter is consistent with technical discussions typical for such projects.
# Phishing | The email header shows a suspicious sender address format (xycn-vtnhz@perl.org) which doesn't align with typical organizational email structures. Additionally, the date is from 2008, which could indicate an outdated or recycled phishing attempt.
# Phishing | The sender's email address (xycn-vtnhz@perl.org) appears suspicious due to the random string before the domain, which is a common tactic in phishing attempts. Additionally, the email is dated 2008, which is outdated and unusual for a current job offer.
# Legitimate | The sender's email address matches the domain of a known organization (Organic Consumers Association), and the subject matter aligns with topics they might cover. There are no immediate red flags such as suspicious links or requests for sensitive information.
# Phishing | The email header shows a suspicious sender address format (xycn-vtnhz@perl.org) that doesn't align with typical organizational email patterns. Additionally, the job offer details in the subject line are overly specific and could be used to entice recipients into clicking on malicious links or attachments.
# Phishing | The email header contains several red flags: the sender's email address does not match the name "bradley dept," the subject line is vague and uses a suspicious string of characters, and the use of a non-corporate domain (wxs.nl) for what appears to be a personal or departmental communication is unusual.
# Phishing | The email header shows a suspicious sender email address (xycn-vtnhz@perl.org) that does not match typical organizational email patterns, suggesting it may be spoofed.
# Legitimate | The email header appears to be a legitimate communication related to a mailing list or development discussion, as indicated by the subject line "[spambayes-dev]" which suggests it is part of a developer or project mailing list. The sender's email address and domain do not raise immediate red flags, and the receiver's address is consistent with a mailing list format.
# Phishing | The email subject is vague and enticing, which is a common tactic in phishing attempts. The sender's name does not match the email address, which is another red flag. Additionally, the email is sent to a generic-sounding address, which could indicate a mass phishing attempt.
# Phishing | The email header shows signs of phishing: the sender's email address appears suspicious and unrelated to the subject, and the subject line is a common tactic used in phishing to entice recipients with financial incentives.
# Legitimate | The email header appears to be a typical inquiry to a mailing list (r-help) related to statistical software (R), with no immediate signs of phishing such as suspicious links, attachments, or requests for sensitive information. The sender's email address and the subject matter are consistent with a legitimate query to a technical forum.
# Phishing | The subject line "Make your gf happy" is suspicious and often associated with spam or phishing attempts. Additionally, the sender's email domain "cissa-mex.com" does not provide any clear, legitimate context related to the recipient, and the email's content is likely to be unsolicited and potentially malicious.
# Legitimate | The email header appears to be consistent with a job posting from a Perl-related organization, using a domain that matches the context (perl.org). The subject and sender align with a legitimate job-related communication.
# Phishing | The sender's name "andrzej janaki" does not match the email address "linda.groah@kp.org," which is suspicious. Additionally, the email is sent to a challenge domain "gvc.ceas-challenge.cc," which is often used for testing or research purposes, indicating it might be part of a phishing test or exercise.
# Phishing | The sender's email address appears suspicious and unrelated to CNN, using a subdomain of "shag.dealerspace.com" which is not associated with CNN. Additionally, the use of a generic name like "Daily Top 10" and the unusual domain structure are common indicators of phishing attempts.
# Phishing | The subject line "We offer you happiness" is vague and often used in phishing attempts to entice recipients. Additionally, the sender's email address does not match the name "Ruby Holder," which is a common tactic in phishing to disguise the true sender.
# Phishing | The sender's email address uses a suspicious domain (freemail.selfip.org) that does not match the legitimate CNN domain, which is a common tactic in phishing attempts.
# Phishing | The sender's email address (sbogeb_1995@zamilsteel.com) does not match the expected domain for CNN, which should be something like cnn.com. This mismatch is a common indicator of phishing attempts.
# Phishing | The subject line suggests a potentially suspicious offer related to prescription-free medication, which is a common tactic in phishing emails. Additionally, the sender's email address appears to be from a generic or personal email service (packbell.net) rather than a professional or recognizable domain, which is another red flag.
# Phishing | The email header indicates a suspicious sender address that does not match the subject matter, which is typical of phishing attempts. The subject line also suggests a spam-like promotion for replica watches, which is a common phishing tactic.
# Phishing | The sender's email address (ppcwedbyff@gmail.com) does not match the expected domain for someone sending official communications to the Python Mailing List, which would typically come from a python.org address.
# Phishing | The sender's email address appears suspicious with a random string of characters before the domain, which is a common tactic in phishing attempts. Additionally, the subject line "Splendid Health Joy" is vague and could be indicative of spam or phishing content.
# ✅ CoT analysis complete for 'header' emails. File saved at: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/chainofthought/header_sample_75_without_label_cot_predicted.xlsx
# Phishing | The email body contains suspicious elements such as a promise of enhancing physical attributes, which is a common tactic in phishing and spam emails. The language is vague and sensational, aiming to entice the recipient to click on a link. Additionally, the inclusion of an unrelated and disjointed sentence about Nazi tanks suggests a lack of coherence typical of phishing attempts. The URL provided is also suspicious and not associated with a reputable organization.
# Phishing | The email contains a suspicious link and inappropriate content that is commonly associated with phishing attempts. The message is vague, lacks personalization, and uses language designed to entice clicks, which are typical characteristics of phishing emails.
# Legitimate | The email contains consistent branding and formatting typical of a legitimate CNN newsletter. The links appear to direct to CNN's official website, and the email includes standard footer information, such as the company's address and privacy policy. However, it's important to verify the links independently by hovering over them to ensure they lead to the expected domain.
# Legitimate | The email appears to be a technical discussion related to the management of top-level domains (TLDs) within a software project, specifically SpamAssassin. The content is consistent with a developer or technical team conversation about updating code to handle domain names correctly. The inclusion of a Wikipedia link for further information about the .so domain is typical for providing context, and there are no requests for personal information or suspicious links.
# Phishing | The email body contains a suspicious URL with a random string of characters and lacks any context or personalization, which are common indicators of phishing attempts.
# Phishing | The email body is nonsensical and contains a random jumble of characters, which is a common tactic in phishing attempts to bypass spam filters. Legitimate emails typically contain coherent and meaningful content.
# Phishing | The email promotes counterfeit products, which is a common tactic used in phishing scams to lure recipients into clicking on malicious links or providing personal information. Additionally, the mention of "fake" and "replica" watches is a red flag for illegitimacy.
# Legitimate | The email contains consistent branding and formatting typical of a legitimate newsletter from CNN. The links appear to direct to CNN's official website, and the email includes standard footer information about the company and privacy guidelines. Additionally, there are options to manage preferences and unsubscribe, which are common in legitimate newsletters. However, the date is from 2008, which may indicate this is an old email or a test of some sort.
# Legitimate | The email body appears to be a notification from a bug tracking system (Bugzilla) used by Apache SpamAssassin. It includes a link to a bug report and follows a format typical of automated notifications from such systems.
# Legitimate | The email contains consistent formatting, legitimate CNN URLs, and proper branding details. It also includes unsubscribe and preference management links typical of legitimate newsletters.
# Phishing | The email contains several red flags typical of phishing attempts, such as promises to eliminate debt without consequences, lack of personalization, and urging the recipient to visit a suspicious link. Additionally, the offer seems too good to be true, which is a common tactic used in phishing scams.
# Phishing | The email contains a suspicious link to "oemmerchant.com," which is not an official Adobe website. This is a common tactic in phishing emails to lure users into visiting fraudulent sites. Additionally, the email lacks personalization and context, which are typical characteristics of phishing attempts.
# Legitimate | The email contains consistent formatting, valid CNN URLs, and appropriate contact information. The unsubscribe link and privacy guidelines are standard for legitimate newsletters.
# Legitimate | The email contains consistent formatting, valid CNN URLs, and proper branding details. It also includes standard unsubscribe and privacy links, which are typical for legitimate newsletters.
# Phishing | The email contains several red flags typical of phishing attempts: it promotes dubious health benefits, uses a suspicious URL, and lacks professional formatting or contact information. These elements suggest an attempt to lure recipients into clicking the link, potentially leading to malicious sites or scams.
# Legitimate | The email appears to be part of an ongoing conversation about a Trial IRC Certificate Application. The details provided, such as contact information, addresses, and the context of the conversation, are consistent and specific. Additionally, the email has been screened for viruses and malicious code, which is a common practice for legitimate communications. There are no requests for sensitive information or suspicious links, which are typical indicators of phishing attempts.
# Legitimate | The email contains consistent formatting, valid CNN URLs, and appropriate contact information, indicating it is a genuine newsletter from CNN.
# Legitimate | The email contains consistent formatting, valid CNN URLs, and includes standard footer information such as the company's address and privacy guidelines. The unsubscribe link and feedback options are typical for legitimate newsletters.
# Legitimate | The email appears to be a legitimate discussion among users and developers of the TuxOnIce software, a Linux hibernation solution. It includes technical discussions about software bugs, kernel versions, and driver issues, which are typical of open-source project mailing lists. The email does not contain any requests for personal information, suspicious links, or urgent calls to action that are characteristic of phishing attempts.
# Legitimate | The email appears to be a legitimate discussion from a mailing list related to the Weka machine learning workbench. It contains technical discussions and troubleshooting related to software usage, which is typical for such mailing lists. There are no requests for sensitive information, no suspicious links, and the content is consistent with a technical community exchange.
# Legitimate | The email contains specific details and links that appear to be related to a legitimate scientific publication, ScienceNOW, which is associated with the American Association for the Advancement of Science (AAAS). The URLs and unsubscribe information are consistent with a real newsletter.
# Legitimate | The email appears to be a bug report generated by a tool (perlbug) for the Perl programming language. It includes technical details about a specific issue with Perl's handling of integers and floats, and it follows a structured format typical of automated bug reports. There are no requests for personal information, no suspicious links, and the content is consistent with legitimate technical communication.
# Legitimate | The email appears to be a standard mailing list digest from the Wekalist, a mailing list associated with the Weka software, which is a well-known data mining tool. The email includes typical mailing list management instructions, such as how to subscribe or unsubscribe, and the topics listed are relevant to discussions one would expect from a technical mailing list. The URLs and email addresses use a consistent domain associated with the University of Waikato, which is where Weka was developed.
# Legitimate | The email appears to be a version control update notification for a project hosted on SourceForge, specifically related to the Spambayes project. It includes technical details about changes made to a Python file, which is typical for automated commit messages sent to mailing lists for developers. The presence of a mailing list link and a typical SourceForge directory structure further supports its legitimacy.
# Legitimate | The email discusses technical details about disk usage and command-line operations, which is typical of an internal communication among IT or technical staff. There are no signs of phishing, such as requests for sensitive information or suspicious links.
# Phishing | The email contains suspicious elements such as random hashtags, a celebrity name to entice clicks, and a vague call to action ("Go to site!") without any legitimate context or sender information. These are common characteristics of phishing attempts designed to lure recipients into clicking malicious links.
# Phishing | The email body contains suspicious content with references to explicit material and a hyperlink to a potentially malicious website. This is a common tactic used in phishing attempts to lure users into clicking on links that could lead to malware or data theft.
# Legitimate | The email body contains a technical discussion about Linux security, malware, and best practices for maintaining system security. It does not exhibit typical phishing characteristics such as urgent requests for personal information, suspicious links, or attachments. The content is informative and focuses on security awareness rather than attempting to deceive the recipient.
# Phishing | The email contains a suspicious link and inappropriate content, which is a common tactic used in phishing attempts to lure recipients into clicking on potentially harmful links.
# Phishing | The email offers diplomas without any educational requirements, which is a common tactic used in scams. The poor grammar and spelling errors, such as "Bacheelor" and "Doctoraate," further indicate a lack of professionalism. Additionally, the promise of confidentiality and the request for personal information via voicemail are red flags typical of phishing attempts.
# Phishing | The email contains several red flags: the URLs appear to be legitimate CNN links but are suspiciously long and complex, potentially masking malicious redirects. Additionally, the email is dated from 2008, which is unusual for a current email. The unsubscribe link also appears suspicious, as it includes a non-CNN domain. These elements suggest it could be a phishing attempt.
# Phishing | The email contains nonsensical text and random words that do not form coherent sentences, which is a common tactic in phishing emails to bypass spam filters. Additionally, the promise of "the best online chemist service" without any specific details or reputable company information is suspicious.
# Phishing | The email contains a suspicious link and uses vague, enticing language to lure the recipient into clicking it. Additionally, the content is unrelated and disjointed, which is a common characteristic of phishing attempts designed to bypass spam filters.
# Legitimate | The email body contains a technical discussion about Perl programming, specifically about pattern matching and block scoping. It includes code snippets and references to Perl documentation, which are typical in legitimate technical discussions among developers or within programming communities. There are no signs of phishing, such as requests for personal information, suspicious links, or urgent calls to action.
# Legitimate | The email contains specific information about a book inquiry, includes a physical address and contact details for a known bookstore, and is part of a mailing list with a relevant domain. There are no signs of phishing, such as suspicious links or requests for sensitive information.
# Legitimate | The email contains consistent branding, legitimate CNN URLs, and typical newsletter content. The unsubscribe and feedback links are also consistent with CNN's practices.
# Phishing | The email contains a suspicious link and uses inappropriate content to lure the recipient, which is a common tactic in phishing attempts.
# Phishing | The email uses vague language and lacks specific details about the sender or the products. The phrase "Click here!" is a common tactic used in phishing emails to lure recipients into clicking on potentially malicious links.
# Legitimate | The email appears to be a bug report or discussion related to an open-source project, specifically Apache SpamAssassin. It includes technical details about a bug fix and a call for votes, which is typical in open-source project communications. The presence of a link to a known bug tracking system (issues.apache.org) and the structured format of the email suggest it is legitimate.
# Phishing | The email body contains a suspicious link and uses language typical of spam or phishing attempts, such as offering an unspecified "increasing formula" for romantic relationships. The random and unrelated text at the end further suggests it is not a legitimate communication.
# Phishing | The email uses emotional manipulation to prompt a purchase and lacks specific details about the company or product. The generic nature and absence of contact information or a legitimate company name are common phishing indicators.
# Legitimate | The email contains consistent branding and formatting typical of a legitimate CNN newsletter, with links pointing to CNN's official website. Additionally, it includes standard footer information about the company and privacy guidelines, which are common in legitimate newsletters.
# Phishing | The email body consists of nonsensical and random words that do not form coherent sentences or convey any meaningful message. This is a common characteristic of phishing attempts designed to confuse or trick recipients.
# Legitimate | The email discusses technical details about CRM114, a known spam filtering software, and troubleshooting issues with its setup. It includes specific command-line usage and configuration details that are typical of a technical discussion. The email is sent from a mailing list related to CRM114, and there are no requests for sensitive information or suspicious links. The links provided are related to SourceForge and GMX, which are legitimate services.
# Phishing | Brief Reason: The email contains outdated information from 2008, which is unusual for a current email alert. Additionally, the email lacks personalization and contains excessive whitespace, which are common characteristics of phishing emails. The unsubscribe link could potentially lead to a malicious site.
# Legitimate | The email body appears to be a discussion about operating system security, specifically comparing Linux and Windows. It does not contain any suspicious links, requests for personal information, or urgent calls to action that are typical of phishing attempts. The conversation seems to be a technical discussion among users about security practices and perceptions.
# Phishing | The email contains inappropriate content and a suspicious link, which are common indicators of phishing attempts.
# Phishing | Brief Reason: The email appears to be outdated, referencing events and news from 2008, which is unusual for a current newsletter. Additionally, the email lacks personalization, contains excessive whitespace, and includes generic content that could be easily copied from legitimate sources. These characteristics are common in phishing attempts designed to mimic legitimate newsletters to trick recipients into clicking links or providing personal information.
# Legitimate | The email contains multiple elements that suggest it is legitimate, such as consistent formatting, links that appear to direct to CNN's official website, and a detailed footer with contact information and privacy guidelines. Additionally, the email provides options for managing preferences and unsubscribing, which are typical features of legitimate newsletters. However, always exercise caution and verify links independently if unsure.
# Legitimate | The email contains a structured format typical of newsletters, with links pointing to CNN's official website (cnn.com). It includes a privacy policy and unsubscribe options, which are common in legitimate newsletters. However, always verify the sender's email address to ensure authenticity.
# Legitimate | The email provides detailed information about a past event, the CEAS Live Spam Challenge, including dates, location, and contact details. It includes links to reputable institutions (Stanford, IBM, University of Waterloo) and uses a mailing list from Stanford University, which adds credibility. The email does not request personal information or contain suspicious links or attachments, typical of phishing attempts.
# Legitimate | The email content is a technical discussion about a Unix command and its behavior related to disk usage and mount points. There are no requests for sensitive information, no suspicious links, and no urgent or threatening language typical of phishing attempts.
# Legitimate | The email body appears to be a conversation about software versions and personal experiences, with no signs of phishing tactics such as requests for sensitive information, suspicious links, or urgent calls to action. The content is consistent with a discussion among individuals familiar with each other, likely in a forum or mailing list context.
# Legitimate | The email appears to be a bug report notification from the Apache SpamAssassin bug tracking system. It includes a link to an Apache project page, references specific technical details about a bug, and follows a format typical of automated notifications from bug tracking systems.
# Legitimate | The email body provides specific details about a job posting, including a job title, location, terms of employment, and required skills. It includes URLs that appear to be related to Perl job postings, and the email addresses for subscribing and unsubscribing are consistent with a mailing list format. Additionally, the job posting date is from 2008, which suggests it might be an archived or older listing rather than a phishing attempt. However, always verify URLs independently to ensure they lead to legitimate sites.
# Legitimate | The email provides detailed job information, including a specific job title, company name (BBC), and a consistent format with URLs that appear to be related to legitimate job postings. The URLs are from known domains (perl.org and bbc.co.uk), which are credible sources for job listings. Additionally, the email includes subscription management options typical for mailing lists, further indicating its legitimacy.
# Legitimate | The email appears to be a newsletter from the Organic Consumers Association, containing detailed information on organic and sustainability topics, with links to articles and actions. The content is consistent with a legitimate newsletter, and there are no immediate signs of phishing, such as requests for sensitive information or suspicious links.
# Legitimate | The email provides specific job details, including a job title, company name, location, and a detailed job description. It includes URLs that appear to be related to legitimate job postings and the company mentioned, Epsilon Interactive. The email also provides clear instructions for subscribing or unsubscribing from the mailing list, which is typical for legitimate job postings. However, it is important to verify the URLs independently to ensure they lead to legitimate websites.
# Phishing | The email contains several red flags typical of phishing attempts: a sensational subject line designed to provoke curiosity, random characters that suggest obfuscation or an attempt to bypass spam filters, and a vague call to action ("Go to the site") without any context or legitimate source.
# Legitimate | The email provides detailed job information, including a specific job title, company name, location, and job requirements. It includes URLs that appear to be related to legitimate job postings and company websites. Additionally, the email does not request sensitive personal information or contain suspicious links, which are common indicators of phishing attempts.
# Legitimate | The email appears to be a genuine request for assistance with a technical issue related to spam filtering software. The language used is consistent with someone experiencing a problem and seeking help, and there are no typical phishing indicators such as urgent requests for personal information, suspicious links, or attachments. Additionally, the context and details provided align with a legitimate technical inquiry.
# Phishing | The email uses enticing language to lure recipients into clicking a link, which is a common tactic in phishing scams. The link provided is suspicious and could lead to a malicious site. Additionally, the email lacks personalization and specific details that would typically be present in legitimate communications.
# Phishing | The email contains several red flags typical of phishing attempts: it offers a product with guaranteed results, which is a common tactic to lure victims; it lacks personal greeting or specific details; and it uses poor grammar and formatting, which are often indicators of phishing.
# Legitimate | The email appears to be a genuine inquiry about statistical analysis using R, specifically regarding MANOVA and mixed models. It references specific statistical functions and packages in R, and includes a signature with a mailing list link related to R, which is consistent with a legitimate request for help from a community or mailing list dedicated to R programming.
# Phishing | The email contains suspicious and inappropriate content, including a link that is likely malicious. The language used is typical of spam or phishing attempts, aiming to entice the recipient with promises of personal benefits. Additionally, the abrupt and incoherent transition to a United Nations report suggests an attempt to appear legitimate, which is a common tactic in phishing emails.
# Legitimate | The email provides a detailed job listing with specific information such as job title, company name, location, pay rate, and contact details. The URLs and email addresses are consistent with the context of a job listing on a known platform (jobs.perl.org), and there are no suspicious requests for personal information or financial details.
# Phishing | The email body is vague, lacks personalization, and contains a call to action with a suspicious link, which are common characteristics of phishing attempts.
# Legitimate | The email contains consistent branding and formatting typical of CNN newsletters, with valid-looking URLs pointing to CNN's domain. The footer includes standard information about the company and links to manage preferences, which is typical for legitimate newsletters.
# Phishing | The email contains nonsensical and random text at the end, which is a common tactic in phishing emails to bypass spam filters. Additionally, the email lacks specific details, such as the name of the company or contact information, which are typically present in legitimate communications.
# Legitimate | The email appears to be a legitimate newsletter from CNN, containing structured content with links to CNN's website, proper branding, and a clear unsubscribe option. The URLs are consistent with CNN's domain, and there are no immediate signs of phishing such as misspellings, suspicious links, or requests for personal information.
# Legitimate | The email contains links that appear to be from CNN's official domain (cnn.com), includes a physical address, and provides options to manage email preferences and unsubscribe, which are typical characteristics of legitimate newsletters. However, always verify by checking the sender's email address and ensuring links are safe before clicking.
# Phishing | The email promotes the sale of prescription drugs without requiring a doctor's visit, which is illegal and a common tactic used in phishing scams. The offer of unlimited quantities and the emphasis on convenience and low cost are red flags. Additionally, the website link provided is suspicious and likely not a legitimate or licensed pharmacy.
# Phishing | The email promotes replica luxury items, which is often associated with scams. The URL provided is suspicious and not related to any legitimate brand.
# Legitimate | The email content appears to be a summary of discussions and updates from a Python development mailing list. It includes detailed technical discussions, references to Python Enhancement Proposals (PEPs), and links to Python-related resources. The language and structure are consistent with a legitimate technical mailing list update, and there are no requests for personal information or suspicious links.
# Phishing | The email contains a suspicious link that does not match the context of the message, lacks personalization, and includes random text fragments, which are common indicators of phishing attempts.
# ✅ CoT analysis complete for 'body' emails. File saved at: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/chainofthought/body_sample_75_without_label_cot_predicted.xlsx
# Phishing | The email exhibits several characteristics of a phishing attempt: it contains a suspicious and unsolicited message with a potentially harmful link, uses manipulative language to provoke an emotional response, and lacks any personal or professional context. Additionally, the sender's email address and the content of the message do not align with any legitimate business communication.
# Phishing | The email contains several red flags typical of phishing attempts: the sender's email address is suspicious and not professional, the subject line is unrelated to any legitimate business or personal communication, and the body contains a link with a vague and potentially malicious purpose. Additionally, the content is inappropriate and unsolicited, which is a common characteristic of phishing emails.
# Phishing | The sender's email address does not match CNN's official domain, and the email is sent from a suspicious domain (universalnet.psi.br). Additionally, the email contains numerous links, which is a common tactic in phishing attempts to lead recipients to malicious websites.
# Legitimate | The email appears to be a legitimate discussion among developers regarding technical changes to the SpamAssassin project. The sender's email address, although not from a corporate domain, is consistent with open-source project communications. The content is technical and relevant to the subject line, and the included link is to a reputable source (Wikipedia). The email lacks typical phishing indicators such as urgent requests, suspicious links, or attachments.
# Phishing | The email contains several red flags: a suspicious sender address, a vague and misleading subject line, a lack of proper formatting and greeting, and a suspicious URL that does not match the sender's domain.
# ...
# Phishing | The email exhibits several characteristics of a phishing attempt: it contains a vague and enticing subject line, a suspicious link to an unrelated domain, and lacks any personal or specific information that would indicate a legitimate purpose. Additionally, the content is generic and unrelated to the recipient's known activities or interests.
# Legitimate | The email content is a technical discussion about a programming issue related to regex scoping in Perl, which includes code snippets and references to Perl documentation. The sender's email address appears to be from a legitimate organization (crypt.org), and there are no signs of phishing tactics such as requests for personal information, suspicious links, or urgent calls to action. The context and tone are consistent with a professional exchange between programmers.
# Legitimate | The email appears to be a genuine inquiry from a bookstore about a specific book related to a historical event. The sender's details, including the address and contact information, are consistent with a legitimate business. There are no signs of phishing, such as suspicious links or requests for personal information.
# Phishing | The sender's email address does not match CNN's domain, which should be something like @cnn.com. Additionally, the email is sent to a suspicious domain (gvc.ceas-challenge.cc) rather than a typical personal or corporate email address. These discrepancies suggest it is not a legitimate email from CNN.
# Phishing | The email contains several red flags typical of phishing attempts: a suspicious and unrelated subject line, a generic and vague message body, and an external link that could lead to a malicious website. Additionally, the lack of a full sender's email address and the unusual context suggest it is not legitimate.
# Phishing | The email contains several red flags: a suspicious subject line that is unrelated to any legitimate business communication, a generic and vague body message, and a call to action to "Click here!" without providing any context or details. Additionally, the sender's email address does not match the content or context of the message, and the formatting is inconsistent, which is typical of phishing attempts.
# Legitimate | The email appears to be a legitimate bug report notification from the Apache SpamAssassin project. The sender's address is from the "issues.apache.org" domain, which is consistent with a bug tracking system. The content of the email discusses technical details related to bug fixes and voting procedures, which are typical in open-source project communications. Additionally, there are no suspicious links or requests for personal information.
# Phishing | The email contains several red flags: a suspicious and unrelated subject line, a generic and vague body message promoting a "new increasing formula," and a link to an unrelated and potentially malicious website (http://milddear.com/). Additionally, the sender's email address does not match the content or context, suggesting it may be spoofed.
# Phishing | The email exhibits several phishing characteristics: it comes from an unusual sender address that does not match the subject matter, it promotes a product in a way that is typical of spam, and it lacks personalization or specific details that would indicate a legitimate communication. Additionally, the email's formatting is poor, and it uses emotional manipulation to prompt immediate action, which is common in phishing attempts.
# Phishing | The email is suspicious because the sender's email address does not match the official CNN domain, and the unsubscribe link contains a suspicious URL that does not align with CNN's typical web addresses.
# Phishing | The email contains nonsensical and random text, lacks a clear purpose, and uses an unusual sender address, which are common characteristics of phishing attempts.
# Legitimate | The email appears to be a legitimate message from a user discussing technical issues with CRM114, a mail filtering program. The sender is asking for help with a specific problem related to email filtering, and the content is consistent with a technical discussion. The email includes technical details and commands relevant to CRM114, and it is sent to a SourceForge mailing list, which is a common platform for open-source project discussions. There are no signs of phishing, such as requests for personal information or suspicious links.
# Legitimate | The email appears to be a legitimate news alert from the Winnipeg Free Press. It includes specific details such as the sender's email address matching the domain of the Winnipeg Free Press, a clear subject line related to breaking news, and a structured format typical of news alerts. Additionally, it provides an option to unsubscribe, which is common in legitimate email communications. There are no immediate signs of phishing, such as suspicious links or requests for personal information.
# Legitimate | The email appears to be a legitimate discussion on a mailing list about operating systems, specifically Linux and Windows security. The content is technical and consistent with typical discussions among users and developers in open-source communities. There are no requests for personal information, suspicious links, or urgent calls to action that are characteristic of phishing attempts.
# Phishing | The email contains a suspicious link and inappropriate content, which are common indicators of phishing attempts. Additionally, the subject and body are unrelated to any legitimate business communication.
# Legitimate | The email appears to be a legitimate newsletter from NBC11.com, a local NBC affiliate. The sender's email address (KNTV@nbclocal.com) matches the format of a local NBC station, and the content is consistent with a typical news update, including stories, photo galleries, and videos. Additionally, there are no suspicious links or requests for personal information, and the email includes standard elements like an unsubscribe option and a privacy policy notice.
# Phishing | The email is suspicious due to the sender's email address, which does not match CNN's official domain. Additionally, the email format and content, while attempting to mimic a legitimate newsletter, contain inconsistencies such as the use of a non-CNN domain for the sender and the presence of unusual characters and formatting. These are common indicators of phishing attempts.
# Phishing | The email claims to be from CNN.com but is sent from an unrelated domain (jasonjones.com), which is a red flag. Additionally, the unsubscribe link uses a suspicious CGI script URL, which is not typical for legitimate unsubscribe links from reputable companies.
# Legitimate | The email appears to be a legitimate announcement for a past event related to the Conference on Email and Anti-Spam (CEAS). The sender's email domain matches the University of Waterloo, which is consistent with the organizer's affiliation. The email provides detailed information about the event, including dates, location, and contact information, and references a real conference. Additionally, the email includes a link to a mailing list hosted on a reputable domain (stanford.edu), which further supports its legitimacy.
# Legitimate | The email appears to be a technical discussion about a Linux command-line issue related to disk usage, which is typical for a mailing list like opensuse. The sender's email address and the content of the email do not exhibit typical phishing characteristics such as urgent requests, suspicious links, or attachments.
# Legitimate | The email content appears to be a genuine conversation between individuals discussing openSUSE, a Linux distribution. The sender and receiver addresses, subject, and body content are consistent with a typical mailing list discussion. There are no signs of phishing, such as requests for personal information, suspicious links, or urgent calls to action.
# Legitimate | The email appears to be a legitimate bug report notification from the Apache SpamAssassin project. The sender's email address is from the "issues.apache.org" domain, which is consistent with the Apache Software Foundation's domain. The content of the email discusses a bug report and includes a link to the official Apache issue tracker. Additionally, the email format and language are typical of automated notifications from bug tracking systems.
# Legitimate | The email appears to be a legitimate job posting from a Perl-related job board. The sender and receiver addresses are consistent with the Perl organization, the content is detailed and professional, and the URLs provided are relevant to Perl job listings. Additionally, the email includes standard subscription management instructions, which is typical for legitimate mailing lists.
# Legitimate | The email appears to be a legitimate job posting from a Perl jobs mailing list. The sender and receiver addresses are consistent with the domain used for Perl jobs, and the content includes specific job details, a reputable company (BBC), and URLs that match the context of the job description. Additionally, the email provides standard subscription management instructions typical of legitimate mailing lists.
# Legitimate | The email appears to be a legitimate newsletter from the Organic Consumers Association. It includes detailed content typical of a newsletter, such as articles, tips, and calls to action. The sender's email address matches the organization's domain, and the links provided are consistent with the organization's website. There are no requests for personal information or suspicious attachments, which are common indicators of phishing.
# Legitimate | The email appears to be a legitimate job posting from Perl Jobs, a known platform for Perl-related job listings. The sender and receiver addresses are consistent with the domain used for Perl job postings. The content is detailed and specific, including job requirements and company information, which is typical for legitimate job postings. Additionally, the URLs provided are consistent with the context and do not appear suspicious.
# Phishing | The email exhibits several phishing characteristics: a suspicious sender address, a vague and enticing subject line, and a call to action to visit an unspecified site, which is a common tactic used to lure recipients into clicking malicious links.
# Legitimate | The email appears to be a legitimate job posting from a Perl job board. The sender and receiver addresses are consistent with the Perl job board domain, and the content includes specific job details, a clear job description, and links to reputable websites. There are no signs of phishing, such as requests for personal information or suspicious links.
# Legitimate | The email appears to be a genuine request for assistance regarding a technical issue with the SpamBayes software. The sender's email address matches the name provided, and the content is consistent with a user seeking help from a developer mailing list. There are no indications of phishing, such as requests for sensitive information or suspicious links.
# Phishing | The email contains several phishing indicators: a suspicious sender email address, a generic and enticing subject line, and a call to action to visit an external link that could potentially lead to a malicious site. Additionally, the email promotes gambling, which is a common theme in phishing scams.
# Phishing | The email contains several red flags typical of phishing attempts: a suspicious sender email address that does not match the purported content or organization, a generic and unsolicited offer, and a lack of personal greeting or specific details. Additionally, the email uses persuasive language to push a product, which is a common tactic in phishing emails.
# Legitimate | The email is a typical inquiry sent to a mailing list for statistical help, discussing statistical analysis methods in R. The content is relevant to the subject, and there are no signs of phishing, such as suspicious links or requests for personal information.
# Phishing | The email contains several red flags typical of phishing attempts: a suspicious and unrelated subject line, a hyperlink to an unknown and potentially malicious website, and a body content that is irrelevant and inappropriate. Additionally, the email includes a random and incomplete sentence about the United Nations, which does not relate to the rest of the message, further indicating it is not legitimate.
# Legitimate | The email appears to be a legitimate job posting from a Perl-related job board. The sender and receiver addresses are consistent with the Perl organization, and the email includes specific job details, a contact person with a phone number, and a professional email address. Additionally, the job posting URL is consistent with the Perl jobs website, and there are no suspicious links or requests for personal information.
# Phishing | The email has several red flags: the sender's name does not match the email address, the subject line is vague and unrelated to the body, and the body contains a generic message with a suspicious link prompt.
# Phishing | The email is suspicious due to the sender's email address, which does not match CNN's official domain. Additionally, the email contains numerous links that could potentially lead to malicious sites, and the unsubscribe link uses a CGI script, which is unusual for legitimate unsubscribe processes.
# Phishing | The email contains several red flags: a suspicious sender address, a vague and generic subject line, a lack of personalization, and nonsensical text at the end. Additionally, the offer of medications online is a common phishing tactic.
# Phishing | The sender's email address (rezilatn1993@freemail.selfip.org) does not match the official domain of CNN, which should be something like @cnn.com. Additionally, the use of a free email service and the unusual domain (selfip.org) are common indicators of phishing attempts.
# Phishing | The email is suspicious due to the sender's email address, which does not match CNN's domain. Additionally, the email is dated 2008, which is unusual for a current email, and the unsubscribe link uses a CGI script, which is a common phishing tactic.
# Phishing | The email promotes the sale of prescription drugs without a prescription, which is illegal and a common tactic used in phishing scams. The sender's email address is suspicious and not associated with a legitimate pharmacy. Additionally, the email encourages clicking on a link, which could lead to a malicious website.
# Phishing | The email is promoting replica luxury items, which is a common tactic used in phishing scams. The sender's email address does not match the content of the email, and the domain appears unrelated to luxury goods. Additionally, the inclusion of a suspicious URL further indicates phishing intent.
# Legitimate | The email appears to be a summary of discussions from the Python-Dev mailing list, which is a common practice in open-source communities to keep members informed. The content is technical and relevant to Python development, and the email structure aligns with typical mailing list summaries. Additionally, the sender's email, although not from an official domain, does not raise immediate red flags given the context and content.
# Phishing | The email contains several red flags: the sender's email address is suspicious and does not match the subject or content, the subject line and body text are vague and unrelated, and the link provided is not relevant to the message, indicating a potential phishing attempt.
# ✅ CoT analysis complete for 'combined' emails. File saved at: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gpt_llm/output_daata/chainofthought/header_body_sample_75_without_label_cot_predicted.xlsx

# %%
import pandas as pd

# ✅ Function to summarize predictions in any result file
def summarize_predictions(filepath, prompt_type, email_type):
    try:
        # 🔹 Load the prediction result file
        df = pd.read_excel(filepath)

        # 🔹 Clean + Normalize the predictions
        df["Prediction"] = df["Prediction"].str.strip().str.lower()

        # 🔹 Count the number of phishing and legitimate predictions
        phishing_count = (df["Prediction"] == "phishing").sum()
        legit_count = (df["Prediction"] == "legitimate").sum()
        total = len(df)

        # ✅ Print a summary
        print(f"\n📂 {prompt_type.upper()} | 📧 {email_type.upper()}")
        print(f"📊 Total Emails: {total}")
        print(f"🛑 Phishing: {phishing_count}")
        print(f"✅ Legitimate: {legit_count}")
        print("-" * 40)

    except Exception as e:
        print(f"❌ Error processing {filepath}: {e}")

# %%
# 🔹 Base path
base_path = os.path.join(path,'001 Submission','All APIs',  'gpt_llm', 'output_daata')
# "/content/drive/MyDrive/outPut_Folder/gpt_llm/output_daata"

# 🔹 File and config list (path, type)
files_info = [
    # Zero-shot
    (f"{base_path}/zeroshot/header_sample_75_without_label_predicted.xlsx", "zero-shot", "header"),
    (f"{base_path}/zeroshot/body_sample_75_without_label_predicted.xlsx", "zero-shot", "body"),
    (f"{base_path}/zeroshot/header_body_sample_75_without_label_predicted.xlsx", "zero-shot", "combined"),

    # Few-shot
    (f"{base_path}/fewshot/header_sample_75_without_label_fewshot_predicted.xlsx", "few-shot", "header"),
    (f"{base_path}/fewshot/body_sample_75_without_label_fewshot_predicted.xlsx", "few-shot", "body"),
    (f"{base_path}/fewshot/header_body_sample_75_without_label_fewshot_predicted.xlsx", "few-shot", "combined"),

    # Chain-of-Thought
    (f"{base_path}/chainofthought/header_sample_75_without_label_cot_predicted.xlsx", "chain-of-thought", "header"),
    (f"{base_path}/chainofthought/body_sample_75_without_label_cot_predicted.xlsx", "chain-of-thought", "body"),
    (f"{base_path}/chainofthought/header_body_sample_75_without_label_cot_predicted.xlsx", "chain-of-thought", "combined"),
]

# ✅ Run summaries
for file_path, prompt_type, email_type in files_info:
    summarize_predictions(file_path, prompt_type, email_type)
# Out:
# 📂 ZERO-SHOT | 📧 HEADER
# 📊 Total Emails: 75
# 🛑 Phishing: 51
# ✅ Legitimate: 24
# ----------------------------------------
#
# 📂 ZERO-SHOT | 📧 BODY
# 📊 Total Emails: 75
# 🛑 Phishing: 29
# ✅ Legitimate: 46
# ----------------------------------------
#
# 📂 ZERO-SHOT | 📧 COMBINED
# 📊 Total Emails: 75
# 🛑 Phishing: 31
# ✅ Legitimate: 44
# ----------------------------------------
#
# 📂 FEW-SHOT | 📧 HEADER
# 📊 Total Emails: 75
# 🛑 Phishing: 44
# ✅ Legitimate: 31
# ----------------------------------------
#
# 📂 FEW-SHOT | 📧 BODY
# 📊 Total Emails: 75
# 🛑 Phishing: 27
# ✅ Legitimate: 46
# ----------------------------------------
#
# 📂 FEW-SHOT | 📧 COMBINED
# 📊 Total Emails: 75
# 🛑 Phishing: 30
# ✅ Legitimate: 45
# ----------------------------------------
#
# 📂 CHAIN-OF-THOUGHT | 📧 HEADER
# 📊 Total Emails: 75
# 🛑 Phishing: 60
# ✅ Legitimate: 15
# ----------------------------------------
#
# 📂 CHAIN-OF-THOUGHT | 📧 BODY
# 📊 Total Emails: 75
# 🛑 Phishing: 32
# ✅ Legitimate: 43
# ----------------------------------------
#
# 📂 CHAIN-OF-THOUGHT | 📧 COMBINED
# 📊 Total Emails: 75
# 🛑 Phishing: 45
# ✅ Legitimate: 30
# ----------------------------------------

# %% [markdown]
# # end of code
